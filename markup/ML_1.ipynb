# %%
import json
import re
import requests
import os
import glob
import nltk
nltk.download('stopwords')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing  import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import f1_score
from IPython.core.display import HTML, display
import pymorphy2
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/hackabong/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
path = 'res_threads'
all_file = open('train.csv', mode='w', encoding='utf8')
for dirpath, dirnames, filenames in os.walk(path):
    for file in filenames:
        with open(dirpath + "//" + file, mode='r', encoding='utf8') as f:
            all_file.write(f.read())

# %%
train_df = pd.read_csv("train.csv", names = ['Text', 'Target'])

train_df.head()
# Out:
#                                                 Text  Target
# 0  мне 18 лет  я учусь в вузе на программистая яв...       0
# 1  это мои сформировавшиеся взгляды  ради которых...       0
# 2  я веган  потому что мне не плевать на окружающ...       0
# 3                 здоровым можно быть и на веганстве       0
# 4  я за лгбт  потому что геи  бишки и все небинар...       0

# %%
train_df.shape
# Out:
# (10406, 2)

# %%
train_df.dropna(axis=0, inplace=True)

# %%
train_df.shape
# Out:
# (10404, 2)

# %%
train_df['Target'].value_counts()
# Out:
# 0    6920
# 1    3484
# Name: Target, dtype: int64

# %%
list_corpus = train_df["Text"].tolist()
list_labels = train_df["Target"].tolist()

X_train, X_test, y_train, y_test = train_test_split(list_corpus, list_labels, test_size=0.3, 
                                                                                random_state=40)

# %%
def tfidf(data):
    tfidf_vectorizer = TfidfVectorizer()

    train = tfidf_vectorizer.fit_transform(data)

    return train, tfidf_vectorizer

X_train_tfidf, tfidf_vectorizer = tfidf(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %%
clf_tfidf = LogisticRegression(C=30.0, class_weight='balanced', solver='newton-cg', 
                         multi_class='multinomial', n_jobs=-1, random_state=40)
clf_tfidf.fit(X_train_tfidf, y_train)

y_predicted_tfidf = clf_tfidf.predict(X_test_tfidf)

# %%
f1_score(y_test, y_predicted_tfidf)
# Out:
# 0.6441162458313483

# %%
np.mean(y_test == y_predicted_tfidf)
# Out:
# 0.7607303010890455

# %%
df_res = pd.DataFrame({'Text': X_test, 'Target': y_predicted_tfidf})

df_res.head()
# Out:
#                                                 Text  Target
# 0  чтобы я в снегурочку нарядился и стишок ему пр...       0
# 1  в совке более менее могли делать лишь ракеты и...       1
# 2                                   вообще непонятно       0
# 3                                   антена для радио       0
# 4  это кпт  например  просто всякие полезные мело...       0

# %%
df_comp = pd.DataFrame({'Text': X_test, 'Target': y_test})

df_comp.head()
# Out:
#                                                 Text  Target
# 0  чтобы я в снегурочку нарядился и стишок ему пр...       0
# 1  в совке более менее могли делать лишь ракеты и...       1
# 2                                   вообще непонятно       0
# 3                                   антена для радио       0
# 4  это кпт  например  просто всякие полезные мело...       0

# %%
morph = pymorphy2.MorphAnalyzer()
def normalize(x):
    p = morph.parse(x)[0]
    return p.normal_form

input_str = ["Ты дурак"]
input_str = [' '.join(list(map(normalize , input_str[0].split())))]
input_str_test = tfidf_vectorizer.transform(input_str)
result = clf_tfidf.predict(input_str_test)

print("Кибербуллинг" if result[0] == 1 else "Не кибербуллинг")
# Out:
# Не кибербуллинг

# %%
input_str_test = tfidf_vectorizer.transform(input_str)

input_str_test
# Out:
# <1x14809 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>

# %%
result = clf_tfidf.predict(input_str_test)

result[0]
# Out:
# 1

# %%
train_df['Text'].duplicated().value_counts()
# Out:
# False    7912
# True     2465
# Name: Text, dtype: int64

# %%
TOKEN_PATTERN = "[а-яё]+"

# %%
def tokenize(text):
    return re.findall(TOKEN_PATTERN, text.lower())

docs = [tokenize(text) for text in list_corpus]

# %%
docs[0]
# Out:
# ['мне',
#  'лет',
#  'я',
#  'учусь',
#  'в',
#  'вузе',
#  'на',
#  'программистая',
#  'являюсь',
#  'веганом',
#  'лгбт',
#  'активистом',
#  'мультикультуралист',
#  'феминист',
#  'леволибералом',
#  'и',
#  'научный',
#  'атеист']

# %%
from collections import *
occurence = Counter()

for doc in docs:
    for token in doc:
        occurence[token] += 1

# %%
occurence.most_common(20)
# Out:
# [('и', 2783),
#  ('в', 2410),
#  ('не', 2386),
#  ('на', 1785),
#  ('что', 1292),
#  ('с', 1104),
#  ('а', 1050),
#  ('это', 974),
#  ('я', 912),
#  ('ты', 861),
#  ('то', 815),
#  ('как', 716),
#  ('у', 626),
#  ('если', 509),
#  ('по', 488),
#  ('так', 483),
#  ('за', 460),
#  ('все', 417),
#  ('он', 406),
#  ('из', 380)]

# %%
stopword_set = set(nltk.corpus.stopwords.words('russian'))

# %%
sorted_tokens = sorted(occurence.keys())

# %%
sorted_tokens
# Out:
# ['а',
#  'ааа',
#  'ааааа',
#  'ааааррряяяяя',
#  'ааарряяя',
#  'аахахха',
#  'абапе',
#  'абибасами',
#  'аборт',
#  'абортво',
#  'абортони',
#  'абортя',
#  'абсолютна',
#  'абсолютно',
#  'абсолютный',
#  'абстрагироваться',
#  'абстрактное',
#  'абстрактную',
#  'абсурда',
#  'абу',
#  'абы',
#  'абьюзер',
#  'абьюзера',
#  'абьюзераесть',
#  'аватарке',
#  'аватарки',
#  'августинского',
#  'аве',
#  'авевова',
#  'авивова',
#  'авито',
#  'авой',
#  'авроры',
#  'австралии',
#  'авто',
#  'автобамп',
#  'автомат',
#  'автомате',
#  'автоматом',
#  'автомобиле',
#  'автомобили',
#  'автомобиль',
#  'авторитетно',
#  'авторитетных',
#  'авторитетом',
#  'авторов',
#  'авторучка',
#  'авхавхавхахвха',
#  'ага',
#  'агенства',
#  'агенство',
#  'агентства',
#  'агентстватак',
#  'агентстве',
#  'агентством',
#  'агностиком',
#  'агностицизм',
#  'агрессивные',
#  'агрессивными',
#  'агрессии',
#  'агрессия',
#  'агрессор',
#  'агробыдло',
#  'агропромышленный',
#  'ад',
#  'ада',
#  'адаптации',
#  'адвокатом',
#  'адеквата',
#  'адекватами',
#  'адекватно',
#  'адекватности',
#  'адекватные',
#  'адекватный',
#  'адекватных',
#  'адеквату',
#  'админил',
#  'административками',
#  'административными',
#  'администратор',
#  'аднрейксения',
#  'адрес',
#  'адресной',
#  'аж',
#  'ажи',
#  'азбука',
#  'азбуки',
#  'азер',
#  'азербеки',
#  'азиат',
#  'азиата',
#  'азиатская',
#  'азиаты',
#  'азии',
#  'азию',
#  'азу',
#  'азы',
#  'аи',
#  'аиро',
#  'айкоса',
#  'айкосник',
#  'айсберг',
#  'айти',
#  'айтишник',
#  'айтишники',
#  'айтишников',
#  'айтишного',
#  'ак',
#  'академии',
#  'академики',
#  'акая',
#  'аки',
#  'акк',
#  'аккаунтах',
#  'аккаунте',
#  'аккурат',
#  'аккуратно',
#  'аккуратность',
#  'актер',
#  'актерское',
#  'активами',
#  'активатор',
#  'активист',
#  'активистке',
#  'активистов',
#  'активистом',
#  'активистомв',
#  'активисту',
#  'активно',
#  'активного',
#  'активность',
#  'активных',
#  'актовом',
#  'актуально',
#  'актуальность',
#  'актуальную',
#  'акулами',
#  'акцентом',
#  'акцизы',
#  'акции',
#  'алгебра',
#  'алгебру',
#  'алгоритм',
#  'алгоритмов',
#  'алгоритмы',
#  'александр',
#  'александра',
#  'александров',
#  'александровной',
#  'алексеевна',
#  'алексеевны',
#  'алексей',
#  'алексея',
#  'алена',
#  'аленей',
#  'алеша',
#  'алиментам',
#  'алиментов',
#  'алименты',
#  'алиментыразвод',
#  'алина',
#  'алисой',
#  'алкаш',
#  'алкаша',
#  'алкашей',
#  'алкашь',
#  'алкашьв',
#  'алкашём',
#  'алки',
#  'алкоголиком',
#  'алкоголь',
#  'алла',
#  'аллах',
#  'аллаха',
#  'аллахом',
#  'алмаз',
#  'алсо',
#  'альмера',
#  'альтаир',
#  'альтернатив',
#  'альтруисты',
#  'альфа',
#  'альфач',
#  'альфача',
#  'альфачами',
#  'альфачей',
#  'альфачи',
#  'альфачискилловый',
#  'альфачом',
#  'альфачомнихуя',
#  'альфовости',
#  'альфой',
#  'альфонс',
#  'альфы',
#  'алё',
#  'ам',
#  'амбуланса',
#  'американский',
#  'американских',
#  'американцами',
#  'америкосня',
#  'америку',
#  'амеры',
#  'ами',
#  'аминокислоты',
#  'амплуа',
#  'ампулы',
#  'амудэ',
#  'амурбек',
#  'анализ',
#  'анализами',
#  'анализировать',
#  'анализы',
#  'аналитика',
#  'аналог',
#  'аналогах',
#  'аналогии',
#  'аналогично',
#  'аналогию',
#  'анальным',
#  'ананас',
#  'ананасная',
#  'анархист',
#  'анархия',
#  'анастасия',
#  'ангелина',
#  'ангем',
#  'английский',
#  'английским',
#  'английском',
#  'англицизмов',
#  'англицкага',
#  'англоговорящими',
#  'ангуляре',
#  'андерграунд',
#  'андреевна',
#  'андроеды',
#  'андропова',
#  'андроповым',
#  'андрюха',
#  'андрюху',
#  'анегдот',
#  'анжела',
#  'аниме',
#  'анимедаун',
#  'анимешники',
#  'анимешником',
#  'анимешными',
#  'аниму',
#  'анимцо',
#  'анлимитед',
#  'анна',
#  'ановъ',
#  'анон',
#  'анона',
#  'анонами',
#  'анонессы',
#  'анонимной',
#  'анонимном',
#  'анонов',
#  'анону',
#  'анончик',
#  'анончики',
#  'аноны',
#  'анриала',
#  'анскилед',
#  'ант',
#  'антена',
#  'антенных',
#  'антибиотиками',
#  'антибугурт',
#  'антибугурты',
#  'антикафе',
#  'антисоветской',
#  'антонов',
#  'анус',
#  'ануса',
#  'анусов',
#  'анусы',
#  'ап',
#  'апасный',
#  'апельсины',
#  'апи',
#  'апишку',
#  'аппелировать',
#  'аппеляция',
#  'априори',
#  'апрув',
#  'апрувами',
#  'арабы',
#  'аргумент',
#  'аргументируешь',
#  'аргументируют',
#  'аргументов',
#  'аргументы',
#  'арест',
#  'ариец',
#  'арийский',
#  'арканоид',
#  'армейки',
#  'армии',
#  'армию',
#  'армия',
#  'армянин',
#  'армянина',
#  'аррряяяя',
#  'артек',
#  'артем',
#  'артисты',
#  'артмат',
#  'артос',
#  'артрита',
#  'артур',
#  'артём',
#  'архангельское',
#  'архивах',
#  'архивов',
#  'архивы',
#  'архитектор',
#  'архитектурой',
#  'архитектуру',
#  'аряя',
#  'аряяяя',
#  'аряяяяяя',
#  'ас',
#  'асашай',
#  'асбек',
#  'асинхронные',
#  'асинхронный',
#  'асинхронных',
#  'асм',
#  'асоциалы',
#  'ассемблеры',
#  'ассимилироваться',
#  'ассортимента',
#  'ассоциации',
#  'ассоциироваться',
#  'ассоциируют',
#  'астрономии',
#  'асфальт',
#  'атавизм',
#  'атакуют',
#  'атеизм',
#  'атеист',
#  'атеистов',
#  'атеистолсо',
#  'атеистом',
#  'атеистпанчин',
#  'атеисты',
#  'атенка',
#  'аткривушка',
#  'атмосферный',
#  'атомную',
#  'атрибуты',
#  'атрофировалась',
#  'атрофическом',
#  'аттестат',
#  'аты',
#  'ать',
#  'аугментации',
#  'аудио',
#  'аудит',
#  'аудиторией',
#  'аудитория',
#  'ауе',
#  'ауешное',
#  'ауле',
#  'аулов',
#  'аурбиса',
#  'аутист',
#  'аутистов',
#  'аутичному',
#  'аутсорсит',
#  'аухеть',
#  'аф',
#  'афа',
#  'афк',
#  'африканка',
#  'африканский',
#  'африканцам',
#  'афро',
#  'афроамериканцем',
#  'афроамериканцемпочему',
#  'ах',
#  'ахах',
#  'ахаха',
#  'ахахазазахахехеухухихихиэхэхэхэохохохохойхй',
#  'ахахаха',
#  'ахахахах',
#  'ахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахахахахахахахахахахахааахахахахахахахахахахахахаахахахаахахахахахахаххаахахахахахаххааххаахаххахахахахаххаххахаааахахахахахаххахахахахахахахахахахахахахахахах ...
#  'ахахахаххахаха',
#  'ахахххах',
#  'ахмед',
#  'ахуе',
#  'ахуеешь',
#  'ахуел',
#  'ахуенная',
#  'ахуенно',
#  'ахуеть',
#  'ачас',
#  'ашан',
#  'ашане',
#  'аэродромы',
#  'аэрофотосъемки',
#  'б',
#  'ба',
#  'баар',
#  'баб',
#  'баба',
#  'бабахов',
#  'бабе',
#  'бабка',
#  'бабкам',
#  'бабки',
#  'бабкой',
#  'бабку',
#  'бабло',
#  'баблу',
#  'бабой',
#  'бабок',
#  'бабу',
#  'бабуин',
#  'бабулесы',
#  'бабуль',
#  'бабуля',
#  'бабушка',
#  'бабушке',
#  'бабушки',
#  'бабушкиной',
#  'бабшанов',
#  'бабы',
#  'баг',
#  'багами',
#  'багета',
#  'баги',
#  'багов',
#  'багор',
#  'базарим',
#  'базарить',
#  'базе',
#  'базированный',
#  'базовом',
#  'базовые',
#  'базовыми',
#  'базовых',
#  'базой',
#  'базы',
#  'байки',
#  'байонет',
#  'байт',
#  'байта',
#  'байтоеб',
#  'байтоеблю',
#  'байтоёбства',
#  'баквит',
#  'баклажан',
#  'баклажануборщицашелковицапакетдс',
#  'баклажаны',
#  'баклан',
#  'баксов',
#  'бактерии',
#  'балахон',
#  'балахонбыл',
#  'баленсьяга',
#  'балка',
#  'балкон',
#  'балкона',
#  'балконе',
#  'балконы',
#  'балок',
#  'бамп',
#  'бампай',
#  'бампать',
#  'бампечек',
#  'бампик',
#  'бан',
#  'банальное',
#  'банда',
#  'бандикам',
#  'бандитами',
#  'бандитов',
#  'бане',
#  'банит',
#  'банка',
#  'банке',
#  'банкета',
#  'банки',
#  'банковской',
#  'банкой',
#  'банком',
#  'банкоматов',
#  'банку',
#  'банок',
#  'баночек',
#  'банхаммер',
#  'баптиста',
#  'баранку',
#  'барахтающего',
#  'барбадосе',
#  'бардюр',
#  'баребух',
#  'баребухи',
#  'барин',
#  'барп',
#  'бассбуст',
#  'басы',
#  'батарею',
#  'батарея',
#  'бате',
#  'батей',
#  'бати',
#  'батина',
#  'батиной',
#  'батон',
#  'батонфайл',
#  'батонфайликластикбордюр',
#  'батонфайликластикбордюрподдсье',
#  'батонфайликрезинкабордюр',
#  'батонфайликстеркабордюр',
#  'батонфайликстёркабардюр',
#  'батонфайлластик',
#  'батонфайлластикбордюр',
#  'батонфайлластикбордюрмимо',
#  'батонфайлластикпоребрикдс',
#  'батонфайлстерка',
#  'батонфайлстеркапаребрик',
#  'батонфайлстиралкап',
#  'батонфайлстёркабордюр',
#  'баторподключиться',
#  'батрачу',
#  'баттхерта',
#  'баттхёрт',
#  'бать',
#  'батька',
#  'батю',
#  'батя',
#  'бафомета',
#  'бахает',
#  'бахеиле',
#  'бахетле',
#  'башка',
#  'башке',
#  'башкой',
#  'башку',
#  'башмаки',
#  'башни',
#  'башню',
#  'башорге',
#  'бвремя',
#  'бдительный',
#  'бдсм',
#  'бе',
#  'бегали',
#  'бегать',
#  'бегая',
#  'бегом',
#  'бегут',
#  'беда',
#  'бедеее',
#  'бедности',
#  'бедные',
#  'бедняге',
#  'бедуины',
#  'бежать',
#  'без',
#  'безалкогольный',
#  'бездарную',
#  'бездорожья',
#  'безлактозное',
#  'безмозглому',
#  'безмозглые',
#  'безнаказанно',
#  'безобидный',
#  'безопасное',
#  'безопасности',
#  'безотцовщина',
#  'безработному',
#  'безработный',
#  'безработным',
#  'безудержное',
#  'безумия',
#  'безусловно',
#  'безуспешно',
#  'бейли',
#  'бекенд',
#  'белая',
#  'белки',
#  'белобородова',
#  'белого',
#  'белой',
#  'белокурыми',
#  'белоруссию',
#  'белорусы',
#  'белоручка',
#  'белоты',
#  'белы',
#  'белые',
#  'белый',
#  'белых',
#  'бельский',
#  'бенгальский',
#  'бенд',
#  'бенедикт',
#  'бенз',
#  'бензин',
#  'бензином',
#  'берега',
#  'беременеют',
#  'беременного',
#  'беременности',
#  'берете',
#  'берется',
#  'берешь',
#  'бери',
#  'берите',
#  'беру',
#  'берусь',
#  'берут',
#  'берёзе',
#  'берёте',
#  'берёшь',
#  'беситесьда',
#  'бесконечным',
#  'бесконтактные',
#  'бесплатная',
#  'бесплатно',
#  'бесплодная',
#  'бесполезно',
#  'бесполезной',
#  'бесполезны',
#  'бесполезные',
#  'беспомощного',
#  'беспомощном',
#  'беспочвенна',
#  'бесприданницы',
#  'беспруфный',
#  'бессмысленна',
#  'бессмысленно',
#  'бест',
#  'бестолочь',
#  'бесхозной',
#  'бесчисленное',
#  'бесят',
#  'бесятся',
#  'бетельгейзе',
#  'бешенная',
#  'бешенство',
#  'би',
#  'биби',
#  'библиотекарь',
#  'библиотеку',
#  'библию',
#  'бибу',
#  'биг',
#  'бизнес',
#  'бизнеса',
#  'бизнесе',
#  'бизнесмена',
#  'бизнессу',
#  'бизнесу',
#  'бикоз',
#  'билана',
#  'билд',
#  'билдтулзы',
#  'билет',
#  'билета',
#  'билеты',
#  'били',
#  'бился',
#  'бимбо',
#  'бинты',
#  'биологии',
#  'биологически',
#  'биологию',
#  'биологиюих',
#  'биология',
#  'биомусор',
#  'биомусора',
#  'биопроблемные',
#  'биопроблемный',
#  'биопрограмма',
#  'биореактор',
#  'биороботы',
#  'биссескуал',
#  'бит',
#  'битард',
#  'битежки',
#  'битки',
#  'битые',
#  'бить',
#  'бич',
#  'бичара',
#  'бишки',
#  'бл',
#  'бла',
#  'благо',
#  'благоверные',
#  'благоволит',
#  'благодари',
#  'благодарю',
#  'благодаря',
#  'благополучие',
#  'благополучия',
#  'благословил',
#  'блат',
#  'блатная',
#  'блату',
#  'блджад',
#  'блдь',
#  'блевали',
#  'бледный',
#  'блеядь',
#  'ближайшего',
#  'ближайшие',
#  'ближайший',
#  'ближе',
#  'ближнем',
#  'близкими',
#  'близко',
#  'близкое',
#  'блин',
#  'блины',
#  'блм',
#  'блоге',
#  'блок',
#  'блока',
#  'блокировки',
#  'блондины',
#  'блуд',
#  'блэт',
#  'блюд',
#  'блюда',
#  'блюдо',
#  'бля',
#  'блядб',
#  'блядей',
#  'бляди',
#  'блядины',
#  'блядства',
#  'блядть',
#  'блядун',
#  'блядь',
#  'блять',
#  'блятьче',
#  'бляяяяя',
#  'блёсточки',
#  'бнрите',
#  'бо',
#  'бобак',
#  'бог',
#  'бога',
#  'богатеем',
#  'богатый',
#  'богатым',
#  'богатыми',
#  'богини',
#  'богомерзкий',
#  'богомерзко',
#  'богомерской',
#  'богу',
#  'бодя',
#  'бодяжить',
#  'боевик',
#  'боевого',
#  'боевой',
#  'боевыеми',
#  'боевыми',
#  'боевых',
#  'боец',
#  'боже',
#  'боженька',
#  'божественная',
#  'божественное',
#  'божий',
#  'бои',
#  'боись',
#  'боичике',
#  'бой',
#  'бойфренд',
#  'бойфренда',
#  'бок',
#  'бокал',
#  'бокала',
#  'бокалов',
#  'бокалы',
#  'бокс',
#  'болгенос',
#  'более',
#  'болеет',
#  'болезней',
#  'болезненный',
#  'болезням',
#  'болен',
#  'боли',
#  'болит',
#  'болото',
#  'болотоградцы',
#  'болт',
#  'болтик',
#  'болтики',
#  'болты',
#  'боль',
#  'больжедор',
#  'больжедора',
#  'больниц',
#  'больницавызвал',
#  'больницы',
#  'больничке',
#  'больной',
#  'больные',
#  'больных',
#  'большая',
#  'больше',
#  'большего',
#  'большей',
#  'большие',
#  'больший',
#  'большим',
#  'большинства',
#  'большинстве',
#  'большинство',
#  'большинству',
#  'больших',
#  'большое',
#  'большой',
#  'большую',
#  'бомбасс',
#  'бомбассе',
#  'бомбеж',
#  'бомби',
#  'бомбит',
#  'бомбу',
#  'бомж',
#  'бомжа',
#  'бомжацком',
#  'бомжей',
#  'бомжи',
#  'бомжиху',
#  'бомжовскую',
#  'бонгом',
#  'боньбочки',
#  'борда',
#  'борде',
#  'борду',
#  'борды',
#  'бордьюр',
#  'бордюр',
#  'борец',
#  'борис',
#  'борись',
#  'бородатые',
#  'бородатый',
#  'бороду',
#  'бороться',
#  'бортовой',
#  'борщакекс',
#  'борщей',
#  'борьбе',
#  'борюсь',
#  'борятся',
#  'босая',
#  'босиком',
#  'бот',
#  'бота',
#  'ботвинника',
#  'ботинки',
#  'ботовайпера',
#  'бототред',
#  'боты',
#  'бохато',
#  'бохатого',
#  'боцами',
#  'бочке',
#  'бочкенаряжается',
#  'бою',
#  'боюсь',
#  'боя',
#  'боялись',
#  'боялся',
#  'боярин',
#  'бояршиновым',
#  'боятся',
#  'бояться',
#  'бпир',
#  'бподключиться',
#  'браво',
#  'брага',
#  'брайан',
#  'брак',
#  'брака',
#  'бракао',
#  'браке',
#  'бракзачем',
#  'браки',
#  'браков',
#  'бракодел',
#  'браком',
#  'браконьерский',
#  'браку',
#  'брала',
#  'бралвот',
#  'брали',
#  'брани',
#  'брат',
#  'братан',
#  'братиш',
#  'братишка',
#  'братом',
#  'брать',
#  'браузер',
#  'браузера',
#  'браузере',
#  'браузерку',
#  'брачный',
#  'бред',
#  'бреешь',
#  'брежнева',
#  'брейки',
#  'брил',
#  'британские',
#  'бритах',
#  'бритвами',
#  'бритвы',
#  'брить',
#  'брифинга',
#  'брйек',
#  'брно',
#  'бро',
#  'броне',
#  'бронеребенок',
#  'бросает',
#  'бросай',
#  'бросил',
#  'бросились',
#  'бросился',
#  'бросит',
#  'брось',
#  'брюнеты',
#  'брюнне',
#  'брюс',
#  'брюсом',
#  'брючках',
#  'брюшную',
#  'бтвс',
#  'бубнами',
#  'бугульма',
#  'бугульму',
#  'бугурт',
#  'бугуртит',
#  'бугуртишь',
#  'бугурты',
#  'будем',
#  'будет',
#  'будете',
#  'будетрусачки',
#  'будешь',
#  'будешьнет',
#  'будит',
#  'будто',
#  'буду',
#  'будуаре',
#  'будут',
#  'будучи',
#  'будущего',
#  'будущее',
#  'будущем',
#  'будущему',
#  'будущие',
#  'будущий',
#  'будущих',
#  'будь',
#  'буит',
#  'букв',
#  'буквально',
#  'букет',
#  'буклеты',
#  'булка',
#  'булкамультифораластикбортовой',
#  'булкапапкастиралкаосвальт',
#  'булкапапкастиральная',
#  'булки',
#  'буль',
#  'бумаги',
#  'бумагой',
#  'бумагу',
#  'бумажекстирательная',
#  'бумажки',
#  'бумажкой',
#  'бумер',
#  'бумеров',
#  'бумерская',
#  'бумерские',
#  'бумеры',
#  'бумканья',
#  'бумкать',
#  'бумке',
#  'бункере',
#  'бурак',
#  'бургер',
#  'бурча',
#  ...]

# %%
import pymorphy2
lemmatizer = pymorphy2.MorphAnalyzer()

# %%
lemmatizer_cache = {}

def lemmatize(token):
    if lemmatizer.word_is_known(token):
        if token not in lemmatizer_cache:
            lemmatizer_cache[token] = lemmatizer.parse(token)[0].normal_form
        return lemmatizer_cache[token]
    return token

lemmatized_docs = [[lemmatize(token) for token in text] for text in docs]

cleared_docs = [[token for token in text if token not in stopword_set] for text in lemmatized_docs]

cleared_docs
# Out:
# [['год',
#   'учиться',
#   'вуз',
#   'программистая',
#   'являться',
#   'веганом',
#   'лгбт',
#   'активист',
#   'мультикультуралист',
#   'феминист',
#   'леволибералом',
#   'научный',
#   'атеист'],
#  ['это', 'сформироваться', 'взгляд', 'ради', 'который', 'готовый', 'бороться'],
#  ['веган',
#   'плевать',
#   'окружающий',
#   'среда',
#   'хотеть',
#   'причинять',
#   'вред',
#   'животное'],
#  ['здоровый', 'веганстве'],
#  ['лгбт', 'гей', 'бишки', 'всё', 'небинарные', 'это', 'зайка'],
#  ['любить', 'любой', 'проявление', 'гейства'],
#  ['это', 'личный', 'выбор', 'каждый'],
#  ['хотеть', 'россия', 'проходить', 'лгбт', 'парад'],
#  ['би', 'сексуал'],
#  ['почему',
#   'пофиг',
#   'человек',
#   'заниматься',
#   'спальня',
#   'поддерживать',
#   'феминизм',
#   'женщина',
#   'абсолютный',
#   'равный',
#   'мужчина'],
#  ['век', 'женщина', 'угнетать', 'продолжать', 'сей', 'пора'],
#  ['право',
#   'женщина',
#   'нужно',
#   'уравнять',
#   'появиться',
#   'женщина',
#   'учёный',
#   'писатель',
#   'инженер',
#   'который',
#   'ранний',
#   'давить'],
#  ['женщина',
#   'изменить',
#   'парень',
#   'муж',
#   'это',
#   'её',
#   'дело',
#   'абортя',
#   'мудьтикультаралист'],
#  ['расист', 'это', 'наклеить', 'наклейка', 'надпись', 'идиот'],
#  ['наука', 'давно', 'опровергнуть', 'всё', 'положение', 'расизм'],
#  ['человек', 'должный', 'всё', 'перемешаться', 'раса', 'таковой'],
#  ['всё', 'здоровый', 'счастливый'],
#  ['русский',
#   'девушка',
#   'встречаться',
#   'кавказец',
#   'афроамериканец',
#   'это',
#   'прекрасно'],
#  ['либерал'],
#  ['свобода', 'человек', 'превыше', 'весь'],
#  ['каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'другимтакже',
#   'научный',
#   'атеист'],
#  ['религия', 'это', 'яд', 'никакой', 'бог'],
#  ['наука', 'помогать', 'большой', 'молитва', 'гордиться', 'свой', 'поколение'],
#  ['отличие',
#   'отсталый',
#   'постсовков',
#   'думеров',
#   'понимать',
#   'всё',
#   'простой',
#   'вещь',
#   'весь',
#   'добро',
#   'любовь'],
#  ['няшка'],
#  ['бампик'],
#  ['бампечек'],
#  ['бамп'],
#  [],
#  ['год',
#   'учиться',
#   'вуз',
#   'программист',
#   'являться',
#   'веганом',
#   'лгбт',
#   'активист',
#   'мультикультуралист',
#   'феминист',
#   'леволибералом',
#   'научный',
#   'атеист'],
#  ['это', 'сформироваться', 'взгляд', 'ради', 'который', 'готовый', 'бороться'],
#  ['веган',
#   'плевать',
#   'окружающий',
#   'среда',
#   'хотеть',
#   'причинять',
#   'вред',
#   'животное'],
#  ['здоровый', 'веганстве'],
#  ['лгбт', 'гей', 'бишки', 'всё', 'небинарные', 'это', 'зайка'],
#  ['любить', 'любой', 'проявление', 'гейства'],
#  ['это', 'личный', 'выбор', 'каждый'],
#  ['хотеть', 'россия', 'проходить', 'лгбт', 'парад'],
#  ['би', 'сексуал'],
#  ['почему',
#   'пофиг',
#   'человек',
#   'заниматься',
#   'спальня',
#   'поддерживать',
#   'феминизм',
#   'женщина',
#   'абсолютный',
#   'равный',
#   'мужчина'],
#  ['век', 'женщина', 'угнетать', 'продолжать', 'сей', 'пора'],
#  ['право',
#   'женщина',
#   'нужно',
#   'уравнять',
#   'появиться',
#   'женщина',
#   'учёный',
#   'писатель',
#   'инженер',
#   'который',
#   'ранний',
#   'давить'],
#  ['женщина',
#   'изменить',
#   'парень',
#   'муж',
#   'это',
#   'её',
#   'дело',
#   'аборт',
#   'мудьтикультаралист'],
#  ['расист', 'это', 'наклеить', 'наклейка', 'надпись', 'идиот'],
#  ['наука', 'давно', 'опровергнуть', 'всё', 'положение', 'расизм'],
#  ['человек', 'должный', 'всё', 'перемешаться', 'раса', 'таковой'],
#  ['всё', 'здоровый', 'счастливый'],
#  ['русский',
#   'девушка',
#   'встречаться',
#   'кавказец',
#   'афроамериканец',
#   'это',
#   'прекрасно'],
#  ['либерал'],
#  ['свобода', 'человек', 'превыше', 'весь'],
#  ['каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'также',
#   'научный',
#   'атеист'],
#  ['религия', 'это', 'яд', 'никакой', 'бог'],
#  ['наука', 'помогать', 'большой', 'молитва', 'гордиться', 'свой', 'поколение'],
#  ['отличие',
#   'отсталый',
#   'постсовков',
#   'думеров',
#   'понимать',
#   'всё',
#   'простой',
#   'вещь',
#   'весь',
#   'добро',
#   'любовь'],
#  ['няшка'],
#  ['ого', 'это', 'постирония'],
#  ['мультикультуралистзначение', 'знать'],
#  ['почему',
#   'пофиг',
#   'человек',
#   'заниматься',
#   'спальнепочему',
#   'провести',
#   'гей',
#   'парад',
#   'спальня',
#   'хуила'],
#  ['нахуй', 'феминист'],
#  ['это', 'фемки', 'обоссали'],
#  ['учить', 'мат'],
#  ['часть', 'малый'],
#  [],
#  [],
#  ['лгбт', 'парад'],
#  ['это'],
#  ['блядь', 'обосрался', 'корча', 'смешение', 'раса'],
#  ['научный', 'атеистпанчин', 'рассказать'],
#  ['короче', 'промыть', 'долбоеб'],
#  ['определение',
#   'сначала',
#   'выучить',
#   'прежде',
#   'жирный',
#   'тред',
#   'дваче',
#   'клепать'],
#  ['хотя', 'это', 'смешной'],
#  ['проиграть', 'мамкин', 'тролль', 'унижать', 'надсмехаться'],
#  ['либерал'],
#  ['свобода', 'человек', 'превыше', 'весь'],
#  ['каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'другимсынок',
#   'либерал',
#   'это',
#   'умеренный',
#   'фашист'],
#  ['человек', 'убеждение', 'взгляд', 'промытки', 'путинский'],
#  ['хотя', 'это', 'смешной'],
#  ['смекать'],
#  ['тролляне', 'тролил'],
#  ['либерал'],
#  ['свобода', 'человек', 'превыше', 'весь'],
#  ['отлично',
#   'вопрос',
#   'считать',
#   'гомофобный',
#   'расистский',
#   'нацисткие',
#   'ксенофобные',
#   'любой',
#   'взгляд',
#   'личный',
#   'выбор',
#   'человек',
#   'согласный',
#   'человек',
#   'запрещать',
#   'публично',
#   'высказывать',
#   'свой',
#   'мнение',
#   'иной',
#   'слово',
#   'нацист',
#   'иметь',
#   'точно',
#   'право',
#   'вывесить',
#   'свастика',
#   'представитель',
#   'секс',
#   'меньшинство',
#   'вывесить',
#   'лгбт',
#   'флаг'],
#  ['шкирка',
#   'станок',
#   'пара',
#   'смена',
#   'посмотреть',
#   'настоящий',
#   'жизнь',
#   'понюхать',
#   'порох',
#   'поесть',
#   'смена',
#   'мужик',
#   'каша'],
#  ['поколение',
#   'вырасти',
#   'смузи',
#   'коворкингах',
#   'мечтать',
#   'тьфу',
#   'пидор',
#   'европейский'],
#  ['паста', 'базарить', 'оп', 'жирняк', 'сажи'],
#  [],
#  ['являться',
#   'веганом',
#   'лгбт',
#   'активист',
#   'мультикультуралист',
#   'феминист',
#   'леволибералом',
#   'научный',
#   'атеист'],
#  ['это', 'сформироваться', 'взгляд', 'ради', 'который', 'готовый', 'бороться'],
#  ['пидор', 'чтоли'],
#  ['смотреть', 'дима', 'билан', 'отсосать'],
#  ['негр', 'блм', 'сообщество'],
#  ['причём', 'думеры'],
#  ['похуй',
#   'всё',
#   'это',
#   'мир',
#   'давным',
#   'давно',
#   'мир',
#   'прогнить',
#   'насквозь',
#   'наслаждаться',
#   'свой',
#   'жизнь',
#   'сидя',
#   'пекой',
#   'банка',
#   'пиво',
#   'сигой',
#   'зуб',
#   'размышлять',
#   'звезда',
#   'прочий',
#   'вещь',
#   'который',
#   'намного',
#   'выше',
#   'ваш',
#   'мышиный',
#   'возня'],
#  ['покормить', 'троля', 'извинить'],
#  ['это'],
#  ['взгляд',
#   'запретить',
#   'основа',
#   'урок',
#   'история',
#   'который',
#   'вынести',
#   'человечество'],
#  ['голос', 'фашизм', 'лицо', 'либеразизма'],
#  ['успех', 'программирование', 'научиться'],
#  ['нравиться'],
#  ['свой', 'проект', 'начать', 'делать'],
#  ['мочь', 'простой', 'написать', 'пидор', 'всё'],
#  ['мойдодыр', 'принимать', 'пополнение'],
#  ['кадр', 'нарисовать'],
#  ['пищдуй', 'свая', 'америка', 'дура'],
#  ['нахуй', 'нужон'],
#  ['наслаждаться', 'думеры', 'наслаждаться', 'жизнь'],
#  ['сидя',
#   'пекой',
#   'банка',
#   'пиво',
#   'сигой',
#   'зубахэто',
#   'размышлять',
#   'звезда',
#   'прочий',
#   'вещь',
#   'который',
#   'намного',
#   'вышеэто'],
#  ['вегансрать',
#   'жрать',
#   'земля',
#   'лгбт',
#   'человек',
#   'пофиг',
#   'спальня',
#   'это',
#   'обоюдный',
#   'являться',
#   'насилие'],
#  ['нахуя', 'прайд', 'прочее'],
#  ['пойти', 'нахуй', 'тупой', 'быдло'],
#  ['мимогей',
#   'поддерживать',
#   'феминизмженщины',
#   'равный',
#   'мужчина',
#   'биологически'],
#  ['аборт', 'это', 'убийство'],
#  ['единственный',
#   'равенство',
#   'мужчина',
#   'женщина',
#   'поддерживать',
#   'призыв',
#   'женщина',
#   'снять',
#   'всё',
#   'ограничение',
#   'работа',
#   'баба',
#   'равенство',
#   'суд',
#   'мудьтикультаралист'],
#  ['раса',
#   'равный',
#   'наука',
#   'это',
#   'доказывать',
#   'практика',
#   'либераля',
#   'наука',
#   'помогать',
#   'большой',
#   'молитва',
#   'химический',
#   'оружие',
#   'никак',
#   'помочь',
#   'человечество',
#   'весь',
#   'добро',
#   'любовь'],
#  ['няшка'],
#  ['пойти', 'нахуй', 'спороть', 'паста'],
#  ['всё', 'это', 'замечательный', 'интересно'],
#  ['нахуй', 'информация'],
#  ['чудак',
#   'россия',
#   'жить',
#   'общество',
#   'делиться',
#   'ебало',
#   'сломать',
#   'глубоко',
#   'насрать'],
#  ['алсо', 'репорт', 'вниманиеблядство'],
#  ['пидор', 'либерал', 'классический', 'либерал'],
#  ['взгляд', 'запретить', 'основа', 'урок', 'историии', 'урок', 'история'],
#  ['привести',
#   'аналогия',
#   'попытка',
#   'построить',
#   'социализм',
#   'кончаться',
#   'чемхорошим',
#   'социалист',
#   'позволять',
#   'высказываться'],
#  ['ужасный',
#   'гомофоб',
#   'аргументировать',
#   'запрет',
#   'лгбт',
#   'парадовсловами',
#   'всё',
#   'пидор',
#   'стать',
#   'ответ',
#   'говорить',
#   'мочь',
#   'измениться',
#   'ориентация',
#   'это',
#   'личный',
#   'выбор',
#   'человек',
#   'нацистики',
#   'взгляд',
#   'мочь',
#   'считать',
#   'нужно',
#   'сохранить',
#   'свой',
#   'нация',
#   'почему',
#   'запрещать',
#   'ассоциироваться',
#   'либо',
#   'нация',
#   'отстаивать',
#   'её',
#   'интерес'],
#  ['нахуй', 'информация', 'б'],
#  ['толсто'],
#  ['двачую',
#   'насрать',
#   'всё',
#   'мировой',
#   'течение',
#   'скоро',
#   'исчезнуть',
#   'перестать',
#   'воспринимать',
#   'реальность'],
#  ['скоро',
#   'исчезнуть',
#   'перестать',
#   'воспринимать',
#   'реальностьдалеко',
#   'факт'],
#  ['отличие'],
#  ['абсолютно', 'ебланская', 'паста'],
#  ['скрыть', 'бототред'],
#  ['тред', 'сажизелёному', 'опу', 'говно'],
#  ['толсто'],
#  ['лгбт',
#   'парад',
#   'спальня',
#   'абсолютный',
#   'равный',
#   'угнетать',
#   'лгбт',
#   'рост',
#   'количество',
#   'заболевание',
#   'изнасилование',
#   'ребёнок',
#   'воспитанник',
#   'лесбиянка',
#   'ребёнок',
#   'семья',
#   'гей',
#   'изменять',
#   'свой',
#   'супруг'],
#  ['человек',
#   'воспитанный',
#   'обычный',
#   'полный',
#   'семья',
#   'склонный',
#   'хранить',
#   'верность',
#   'супруг',
#   'изменять',
#   'случай'],
#  ['кроме',
#   'воспитанник',
#   'гомосексуальный',
#   'родитель',
#   'обращаться',
#   'психологический',
#   'помощь',
#   'поскольку',
#   'состояние',
#   'справиться',
#   'депрессия',
#   'неверие',
#   'проблема'],
#  ['исследование',
#   'показать',
#   'пример',
#   'родитель',
#   'влиять',
#   'сексуальный',
#   'ориентация',
#   'ребёнок'],
#  ['воспитываться',
#   'лесбиянка',
#   'ребёнок',
#   'семья',
#   'гей',
#   'уверить',
#   'свой',
#   'гетеросексуальности'],
#  ['это',
#   'вредить',
#   'другимхвхывхвхв',
#   'наука',
#   'опровергнуть',
#   'расизмво',
#   'первый',
#   'нету',
#   'пруфов',
#   'второй',
#   'доказать',
#   'раса',
#   'всё',
#   'здоровый',
#   'ребёнок',
#   'метис',
#   'смешанный',
#   'брак',
#   'подверженный',
#   'некоторый',
#   'болезнь'],
#  ['например',
#   'тёмный',
#   'цвет',
#   'кожа',
#   'большой',
#   'содержание',
#   'меланин',
#   'позволять',
#   'африканец',
#   'жить',
#   'палящий',
#   'солнце'],
#  ['однако',
#   'европеец',
#   'среда',
#   'получать',
#   'большой',
#   'ультрафиолет',
#   'длительный',
#   'солнечный',
#   'излучение',
#   'мочь',
#   'заболеть',
#   'рак',
#   'кожа'],
#  ['соответственно',
#   'ребёнок',
#   'пара',
#   'также',
#   'выше',
#   'шанс',
#   'получить',
#   'рак'],
#  ['русский',
#   'девушка',
#   'встречаться',
#   'кавказец',
#   'афроамериканец',
#   'это',
#   'прекрасн',
#   'чекай',
#   'пик',
#   'религия',
#   'это',
#   'ядцитирую',
#   'анон',
#   'религия',
#   'усиливать',
#   'воля',
#   'самоконтроль'],
#  ['исследование',
#   'психолог',
#   'майкл',
#   'маккаллоха',
#   'неверующий',
#   'показывать',
#   'приверженность',
#   'религия',
#   'способствовать',
#   'долголетие'],
#  ['отобрать',
#   'результат',
#   'различный',
#   'исследование',
#   'связанный',
#   'изучение',
#   'религиозность',
#   'наблюдать',
#   'участник',
#   'исследование',
#   'течение',
#   'продолжительный',
#   'время'],
#  ['оказаться',
#   'нерелигиозный',
#   'человек',
#   'умирать',
#   'ранний',
#   'вероятность',
#   'дожить',
#   'любой',
#   'определённый',
#   'возраст',
#   'активный',
#   'верующий',
#   'процент',
#   'выше'],
#  ['это',
#   'очень',
#   'серьёзный',
#   'превышение',
#   'учесть',
#   'сравниваться',
#   'живой',
#   'мёртвый',
#   'последующий',
#   'оценка',
#   'подтвердить',
#   'результат',
#   'опубликовать',
#   'год'],
#  ['некоторый',
#   'долгожитель',
#   'безусловно',
#   'считать',
#   'бог',
#   'услышать',
#   'молитва'],
#  ['однако',
#   'социолог',
#   'принимать',
#   'качество',
#   'гипотеза',
#   'божественный',
#   'вмешательство',
#   'невозможность',
#   'проверка',
#   'лабораторный',
#   'условие',
#   'наслать',
#   'земной',
#   'причина'],
#  ['религиозный',
#   'человек',
#   'менее',
#   'склонный',
#   'вредный',
#   'привычка',
#   'пьянство',
#   'рискованный',
#   'секс',
#   'курение',
#   'наркотик'],
#  ['частый',
#   'пристёгиваться',
#   'автомобиль',
#   'посещать',
#   'стоматолог',
#   'принимать',
#   'витамин'],
#  ['пользоваться',
#   'больший',
#   'социальный',
#   'поддержка',
#   'вера',
#   'помогать',
#   'хороший',
#   'справляться',
#   'психологический',
#   'проблема',
#   'жизненный',
#   'невзгодамимаккаллох',
#   'коллега',
#   'брайан',
#   'уиллоуби',
#   'университет',
#   'майами',
#   'проанализировать',
#   'сотня',
#   'исследование',
#   'тема',
#   'религия',
#   'последний',
#   'год',
#   'прислать',
#   'вывод',
#   'самоконтроль',
#   'верующий',
#   'развитой',
#   'хороший',
#   'атеист'],
#  ['результат',
#   'исследование',
#   'опубликовать',
#   'год',
#   'психологический',
#   'бюллетень',
#   'наиболее',
#   'авторитетный',
#   'строгий',
#   'журнал',
#   'область'],
#  ['некоторый',
#   'эффект',
#   'вера',
#   'очевидный',
#   'религия',
#   'поощрять',
#   'семейный',
#   'ценность',
#   'социальный',
#   'гармония'],
#  ['менее',
#   'очевидный',
#   'последствие',
#   'религия',
#   'способствовать',
#   'снижение',
#   'уровень',
#   'внутренний',
#   'конфликт',
#   'личность',
#   'различный',
#   'цель',
#   'ценность'],
#  ['отмечать',
#   'выше',
#   'одновременный',
#   'постановка',
#   'противоречивый',
#   'задача',
#   'ослаблять',
#   'самоконтроль',
#   'вера',
#   'способствовать',
#   'решение',
#   'проблема',
#   'делать',
#   'приоритет',
#   'верующий',
#   'чёткий'],
#  ['религиозность',
#   'затрагивать',
#   'главный',
#   'механизм',
#   'самоконтроль',
#   'укрепление',
#   'сила',
#   'воля',
#   'наблюдение'],
#  ['ещё',
#   'х',
#   'год',
#   'исследователь',
#   'обратить',
#   'внимание',
#   'ученик',
#   'воскресный',
#   'школа',
#   'обладать',
#   'особый',
#   'самодисциплина'],
#  ['данные',
#   'учитель',
#   'родитель',
#   'религиозный',
#   'ребёнок',
#   'значительно',
#   'менее',
#   'импульсивный'],
#  ['неизвестный',
#   'либо',
#   'исследование',
#   'влияние',
#   'регулярный',
#   'молитва',
#   'иной',
#   'религиозный',
#   'практика',
#   'уровень',
#   'самоконтроль',
#   'предположить',
#   'ритуал',
#   'укреплять',
#   'сила',
#   'воля',
#   'подобно',
#   'упражнение',
#   'который',
#   'рассматривать',
#   'сидение',
#   'прямой',
#   'спина',
#   'контролирование',
#   'свой',
#   'речь'],
#  ['простыегенетика',
#   'биология',
#   'расология',
#   'расоведение',
#   'также',
#   'изучение',
#   'отдельный',
#   'соц'],
#  ['груп', 'простой'],
#  ['именно', 'вещь', 'основывать', 'наш', 'позиция'],
#  ['именно',
#   'всё',
#   'вышеперечисленный',
#   'обесценить',
#   'вызывать',
#   'либо',
#   'ненависть',
#   'либо',
#   'подозрение',
#   'толстота'],
#  ['посмотреть'],
#  ['обыкновенный',
#   'вниманиеблядь',
#   'который',
#   'кроме',
#   'свой',
#   'пидарастических',
#   'наклонность',
#   'рассказать',
#   'выделиться',
#   'нечего',
#   'скромно',
#   'потупить',
#   'глазок',
#   'вещать',
#   'свой',
#   'спальня',
#   'огромный',
#   'простыня',
#   'весь',
#   'харкач'],
#  ['кстати',
#   'нормальный',
#   'гей',
#   'который',
#   'действительно',
#   'ограничиваться',
#   'свой',
#   'спальня',
#   'тащить',
#   'свой',
#   'пристрастие',
#   'интернет',
#   'ненавидеть',
#   'гораздо',
#   'большой',
#   'всякий',
#   'милоновых'],
#  ['искренне',
#   'желать',
#   'выпадение',
#   'прямой',
#   'кишка',
#   'фон',
#   'дистрофия',
#   'депрессия',
#   'няша'],
#  ['толстый'],
#  ['наука',
#   'помогать',
#   'большой',
#   'молитваокей',
#   'наука',
#   'поддерижваешь',
#   'трап',
#   'шизик',
#   'который',
#   'нужно',
#   'лечить',
#   'наука'],
#  ['это', 'сформироваться', 'взгляд', 'ради', 'который', 'готовый', 'бороться'],
#  ['вопрос', 'сформировать'],
#  ['трешсмешем', 'прочий', 'педиками'],
#  ['очевидный', 'нахуя', 'бороться', 'чужой', 'взгляд', 'клоун', 'маленький'],
#  ['жир', 'пот'],
#  ['веганхоть', 'говно', 'жрать', 'похуй'],
#  ['хотеть',
#   'россия',
#   'проходить',
#   'лгбт',
#   'парад',
#   'человек',
#   'заниматься',
#   'спальнетолсто'],
#  ['право',
#   'женщина',
#   'нужно',
#   'уравнять',
#   'появиться',
#   'женщина',
#   'учёный',
#   'писатель',
#   'инженер',
#   'который',
#   'ранний',
#   'давить'],
#  ['около'],
#  ['вышеперечисленный', 'женщина', 'стать', 'мочь'],
#  ['покормить'],
#  ['бывать', 'феминист', 'поговорить', 'любой', 'фемкой'],
#  ['год',
#   'учиться',
#   'вуз',
#   'программистая',
#   'являться',
#   'веганом',
#   'лгбт',
#   'активист',
#   'мультикультуралист',
#   'феминист',
#   'леволибералом',
#   'научный',
#   'атеист'],
#  ['это', 'сформироваться', 'взгляд', 'ради', 'который', 'готовый', 'бороться'],
#  ['веган',
#   'плевать',
#   'окружающий',
#   'среда',
#   'хотеть',
#   'причинять',
#   'вред',
#   'животное'],
#  ['здоровый', 'веганстве'],
#  ['лгбт', 'гей', 'бишки', 'всё', 'небинарные', 'это', 'зайка'],
#  ['любить', 'любой', 'проявление', 'гейства'],
#  ['это', 'личный', 'выбор', 'каждый'],
#  ['хотеть', 'россия', 'проходить', 'лгбт', 'парад'],
#  ['би', 'сексуал'],
#  ['почему',
#   'пофиг',
#   'человек',
#   'заниматься',
#   'спальнея',
#   'поддерживать',
#   'феминизм',
#   'женщина',
#   'абсолютный',
#   'равный',
#   'мужчина'],
#  ['век', 'женщина', 'угнетать', 'продолжать', 'сей', 'пора'],
#  ['право',
#   'женщина',
#   'нужно',
#   'уравнять',
#   'появиться',
#   'женщина',
#   'учёный',
#   'писатель',
#   'инженер',
#   'который',
#   'ранний',
#   'давить'],
#  ['женщина',
#   'изменить',
#   'парень',
#   'муж',
#   'это',
#   'её',
#   'дело',
#   'абортя',
#   'мудьтикультаралист'],
#  ['расист', 'это', 'наклеить', 'наклейка', 'надпись', 'идиот'],
#  ['наука', 'давно', 'опровергнуть', 'всё', 'положение', 'расизм'],
#  ['человек', 'должный', 'всё', 'перемешаться', 'раса', 'таковой'],
#  ['всё', 'здоровый', 'счастливый'],
#  ['русский',
#   'девушка',
#   'встречаться',
#   'кавказец',
#   'афроамериканец',
#   'это',
#   'прекрасно'],
#  ['либерал'],
#  ['свобода', 'человек', 'превыше', 'весь'],
#  ['каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'другимтакже',
#   'научный',
#   'атеист'],
#  ['религия', 'это', 'яд', 'никакой', 'бог'],
#  ['наука', 'помогать', 'большой', 'молитвагоржусь', 'свой', 'поколение'],
#  ['отличие',
#   'отсталый',
#   'постсовков',
#   'думеров',
#   'понимать',
#   'всё',
#   'простой',
#   'вещивсем',
#   'добро',
#   'любовь'],
#  ['няшка'],
#  ['мамкин', 'правак'],
#  ['лгбт',
#   'парад',
#   'постелея',
#   'правильно',
#   'понимать',
#   'хотеть',
#   'устроить',
#   'няшную',
#   'постельный',
#   'федерация',
#   'расставить',
#   'территория',
#   'весь',
#   'россия',
#   'кроватка',
#   'всё',
#   'мочь',
#   'сношаться',
#   'прямо',
#   'улица'],
#  ['з'],
#  [],
#  ['вопрос', 'ответ'],
#  ['слишком', 'толсто'],
#  ['запостите', 'чмонделя', 'обернуть', 'радужный', 'тряпка'],
#  ['чёт', 'найти', 'мочь'],
#  ['толсто', 'тонко'],
#  ['найс', 'байт'],
#  ['съебал', 'борд', 'пидераст', 'несчастный'],
#  ['езжать', 'чечня'],
#  ['твой', 'работа', 'нужный', 'большой', 'весь'],
#  ['егор'],
#  ['курс',
#   'веганом',
#   'обрекать',
#   'уничтожение',
#   'несколько',
#   'вид',
#   'животное',
#   'покупать',
#   'различный',
#   'веганскую',
#   'еда',
#   'косвенно',
#   'поддерживать',
#   'вырубка',
#   'лес',
#   'всякий',
#   'говно',
#   'вроде',
#   'манго',
#   'соя'],
#  ['человек', 'должный', 'всё', 'перемешаться', 'раса', 'таковой'],
#  ['чёрный', 'раса', 'должный', 'ассимилироваться', 'исчезнуть'],
#  ['правильно', 'понять'],
#  ['здоровый', 'веганстве'],
#  ['сколько', 'весить'],
#  ['ооооконечно'],
#  ['твой', 'мать', 'сдохнуть', 'проверять'],
#  ['вообще', 'мысль', 'человек', 'принадлежать'],
#  ['человек',
#   'просто',
#   'перенимать',
#   'чужой',
#   'мысль',
#   'спустя',
#   'время',
#   'начинать',
#   'считать',
#   'мысль',
#   'свой'],
#  ['расология', 'расоведение', 'также', 'изучение', 'отдельный', 'соц'],
#  ['груп', 'простой'],
#  ['именно', 'вещь', 'основывать', 'наш', 'позиция'],
#  ['генетика',
#   'биология',
#   'никто',
#   'шарить',
#   'расоведение',
#   'расология',
#   'это',
#   'отличный',
#   'поле',
#   'пиздаболие',
#   'любой',
#   'даун',
#   'заходить',
#   'паблик',
#   'ра',
#   'ы',
#   'минута',
#   'почитать',
#   'нордический',
#   'величие',
#   'выходить',
#   'икспертом',
#   'знатаком',
#   'ещё',
#   'корчое',
#   'иисус',
#   'ариец',
#   'ваще',
#   'арийский',
#   'дух',
#   'всюду',
#   'очень',
#   'серьёзный',
#   'дисциплина'],
#  ['дарасовый', 'борец', 'высрал', 'стена', 'ответ', 'жирнющую', 'жирноту'],
#  ['каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'другимможешь',
#   'примерно',
#   'назвать',
#   'критерий',
#   'вред'],
#  ['белый'],
#  ['человек', 'должный', 'всё', 'перемешаться', 'раса', 'таковой'],
#  ['верно',
#   'нужно',
#   'весь',
#   'лишь',
#   'создать',
#   'миксер',
#   'тара',
#   'размер',
#   'москва',
#   'сунуть',
#   'туда',
#   'всё',
#   'человечество',
#   'помешивать',
#   'миксер',
#   'секунда'],
#  ['порча', 'имущество', 'здоровье'],
#  ['всё'],
#  [],
#  ['оп', 'обосновать', 'почему', 'религия', 'плохо', 'лгбт'],
#  ['рассказать', 'либерал', 'относиться', 'статья', 'ук', 'рф'],
#  ['готовый', 'бороться'],
#  ['слово', 'дело'],
#  ['около',
#   'год',
#   'юношество',
#   'заниматься',
#   'фехтование',
#   'умеренно',
#   'правый',
#   'любить',
#   'всё',
#   'перечислить'],
#  ['предок',
#   'белые',
#   'русский',
#   'человек',
#   'который',
#   'свой',
#   'труд',
#   'достигнуть'],
#  ['везти', 'господь', 'благоволить'],
#  ['выйти', 'против', 'бой', 'меч', 'готовый', 'сражаться', 'свой', 'взгляд'],
#  ['хотеть', 'россия', 'проходить', 'лгбт', 'парад'],
#  ['почему', 'пофиг', 'человек', 'заниматься', 'спальня'],
#  ['здоровый',
#   'веганствеахахахаха',
#   'всё',
#   'небинарные',
#   'это',
#   'зайкихрюк',
#   'хрю',
#   'ахахахах'],
#  ['твой', 'мать', 'сдохнуть', 'проверяйкак'],
#  ['трупоеду', 'припечь'],
#  ['ебанутый'],
#  ['форма',
#   'выражение',
#   'мысль',
#   'сразу',
#   'видно',
#   'тролль',
#   'подобный',
#   'верить'],
#  ['подтралливаешь', 'просто'],
#  ['уебывай'],
#  ['должный'],
#  ['азиатский'],
#  ['мимо', 'ультраправый'],
#  ['около',
#   'год',
#   'юношество',
#   'заниматься',
#   'фехтованиемя',
#   'стрелять',
#   'тире',
#   'огнестрела'],
#  ['давать', 'меч', 'свой', 'оружие'],
#  ['нечестно'],
#  ['это', 'обосрамс'],
#  ['год',
#   'учиться',
#   'вуз',
#   'программист',
#   'являться',
#   'веганом',
#   'лгбт',
#   'активист',
#   'мультикультуралист',
#   'феминист',
#   'леволибералом',
#   'научный',
#   'атеист'],
#  ['это', 'сформироваться', 'взгляд', 'ради', 'который', 'готовый', 'бороться'],
#  ['первый', 'строка', 'толстить'],
#  ['произойти',
#   'принуждение',
#   'действие',
#   'например',
#   'изнасилование',
#   'вред',
#   'имущество',
#   'здоровье',
#   'это',
#   'нормально'],
#  ['двачую'],
#  ['азиат', 'пусть', 'оставаться', 'еврей'],
#  ['сажать', 'нациков'],
#  ['плохо', 'либерал'],
#  ['стрелять', 'уметь', 'слишком'],
#  ['хороший',
#   'средний',
#   'человек',
#   'намного',
#   'плохой',
#   'любой',
#   'регулярный',
#   'практика'],
#  ['дистанция'],
#  ['менее', 'пять', 'метр', 'меч', 'побеждать'],
#  ['толсто'],
#  ['нацист', 'это', 'враждебно', 'настроить', 'человек', 'нация'],
#  ['гей', 'лесбиянка', 'гетеросексуалам', 'правило', 'агрессия', 'проявлять'],
#  ['мимо'],
#  ['около',
#   'год',
#   'юношество',
#   'заниматься',
#   'фехтование',
#   'умеренно',
#   'правыйя',
#   'давать',
#   'хороший'],
#  ['являться',
#   'веганом',
#   'лгбт',
#   'активист',
#   'мультикультуралист',
#   'феминист',
#   'леволибералом',
#   'научный',
#   'атеист'],
#  ['это', 'сформироваться', 'взгляд', 'ради', 'который', 'готовый', 'бороться'],
#  ['слишком', 'буква', 'давать', 'помочь'],
#  ['просто', 'долбоёб'],
#  ['твой', 'пост', 'левак', 'богомерзкий'],
#  ['ладный'],
#  ['гавно', 'выйти', 'связь'],
#  ['жирно', 'покормилокороче', 'оп', 'хуй', 'говно', 'тред', 'жирный', 'сага'],
#  ['лгбт', 'перетолстил', 'далёкий', 'читать'],
#  ['гей', 'пидарас', 'лгбт', 'ёбаный', 'ересь'],
#  ['жить',
#   'православный',
#   'государство',
#   'подобный',
#   'высказывание',
#   'оскорблять',
#   'весь',
#   'житель',
#   'наш',
#   'великий',
#   'страна'],
#  ['сколько', 'год', 'сформироваться', 'взгляд'],
#  ['учиться',
#   'вуз',
#   'программист',
#   'являться',
#   'лгбт',
#   'активистомв',
#   'это',
#   'необычный',
#   'всё',
#   'программист',
#   'открытый',
#   'тайный',
#   'гомосексуал'],
#  ['это', 'первый', 'строка', 'оп', 'пост', 'глаз', 'протереть', 'стекломоя'],
#  ['православный', 'государствебегом', 'урок', 'школьник'],
#  ['рашке', 'светский', 'государство'],
#  ['дело'],
#  ['двачую'],
#  ['оскорблять', 'например'],
#  ['любой',
#   'сорт',
#   'дегенерат',
#   'похуй',
#   'ебанько',
#   'пидарков',
#   'алкаш',
#   'православнутых'],
#  ['веганом',
#   'лгбт',
#   'активист',
#   'мультикультуралист',
#   'феминист',
#   'леволибералом',
#   'научный',
#   'атеист'],
#  ['святой', 'жирнота', 'братишка'],
#  ['левак', 'сражаться', 'меч'],
#  ['летничего', 'твой', 'возраст'],
#  ['пройти'],
#  ['сажать', 'человек', 'слово', 'убеждение', 'это', 'либерализм', 'фашизм'],
#  ['лгбт',
#   'активист',
#   'мультикультуралист',
#   'феминист',
#   'леволибераломсэр',
#   'троллируете',
#   'слишком',
#   'толстопожалуйста',
#   'попробовать',
#   'тонкий'],
#  ['хуй',
#   'идти',
#   'просто',
#   'читать',
#   'внимательно',
#   'параша',
#   'идиот',
#   'смотреть',
#   'взахлёб',
#   'говно',
#   'толстый',
#   'это',
#   'жрать'],
#  ['насмерть', 'хулить'],
#  ['понимать', 'свобода', 'это', 'абстрактный', 'понятие'],
#  ['толсто', 'попробовать', 'тонкий'],
#  ['православный',
#   'государстветруп',
#   'убийца',
#   'царский',
#   'семья',
#   'скоро',
#   'убрать',
#   'красный',
#   'площадь'],
#  ['являться', 'веганомпо', 'хороший', 'завидовать'],
#  ['ломать',
#   'свой',
#   'диета',
#   'это',
#   'охуеть',
#   'тяжело',
#   'особенно',
#   'готовить'],
#  ['общий', 'добро'],
#  ['двачую'],
#  ['никто',
#   'назвать',
#   'фашист',
#   'кроме',
#   'тупой',
#   'нациков',
#   'который',
#   'набутылят',
#   'статья'],
#  ['изнасиловать', 'вред', 'здоровье', 'невозможно'],
#  ['поход', 'еблан'],
#  ['веган',
#   'плевать',
#   'окружающий',
#   'средуокружающей',
#   'среда',
#   'похуй',
#   'жрать',
#   'срёшь'],
#  ['похуй', 'последствие', 'свой', 'деяние'],
#  ['поддерживать', 'феминизм', 'женщина', 'абсолютный', 'равный', 'мужчина'],
#  ['ага'],
#  ['феминистический', 'движение', 'давно', 'равный', 'право'],
#  ['мультикультуралист'],
#  ['поздравлять'],
#  ['ахмед',
#   'мультикультуралист',
#   'твой',
#   'убеждение',
#   'хотеть',
#   'отрезать',
#   'голова'],
#  ['плюс', 'путать', 'нетерпимость', 'раса', 'культура'],
#  ['либералэто', 'вообще', 'диагноз'],
#  ['также', 'научный', 'атеист'],
#  ['религия', 'это', 'яд', 'никакой', 'бог'],
#  ['человек', 'наука', 'агностик'],
#  ['знать', 'бог'],
#  ['надеяться', 'просто', 'троллишь', 'это', 'высером'],
#  ['ролл'],
#  ['вред', 'здоровье', 'число', 'психический', 'изнасилование'],
#  ['являться',
#   'веганом',
#   'лгбт',
#   'активист',
#   'мультикультуралист',
#   'феминист',
#   'леволибералом',
#   'научный',
#   'атеист'],
#  ['далёкий', 'читать'],
#  [],
#  ['предок',
#   'белые',
#   'русский',
#   'человек',
#   'это',
#   'невозможно',
#   'чисто',
#   'физически'],
#  ['похуй', 'последствие', 'свой', 'деяние'],
#  ['это', 'иметься', 'ввиду', 'окружающий', 'среда'],
#  ['всё',
#   'тема',
#   'соображать',
#   'господин',
#   'собраться',
#   'хотеться',
#   'поинтересоваться',
#   'атеист',
#   'считать',
#   'национализм',
#   'это',
#   'заебок',
#   'загон',
#   'вроде',
#   'запрет',
#   'раса',
#   'просто',
#   'должный',
#   'помощь',
#   'свой',
#   'лгбт',
#   'считать',
#   'лёгкий',
#   'отклонение',
#   'норма',
#   'вроде',
#   'человек',
#   'окр',
#   'который',
#   'никто',
#   'никак',
#   'ограничивать',
#   'относиться',
#   'нормально'],
#  ['безусловно',
#   'сторонник',
#   'равный',
#   'право',
#   'женщина',
#   'мужчина',
#   'считать',
#   'женщина',
#   'принуждать',
#   'мужской',
#   'профессия',
#   'наука',
#   'выйти',
#   'уровень',
#   'мужчина',
#   'настоящий',
#   'опора',
#   'например',
#   'викинг'],
#  ['рыночек',
#   'протекция',
#   'гражданин',
#   'который',
#   'определяться',
#   'происхождение'],
#  [],
#  ['хотеть', 'россия', 'проходить', 'лгбт', 'парад'],
#  ['почему', 'пофиг', 'человек', 'заниматься', 'спальня'],
#  ['откуда', 'подобный', 'примат', 'конкретно', 'тупизна'],
#  ['обычный', 'фашист'],
#  ['нлрмис', 'плез'],
#  ['нормис', 'взлядов', 'кратко'],
#  ['лгбт', 'активист', 'феминист', 'мудьтикультаралистну', 'сказати'],
#  ['ислам', 'право', 'счёт', 'женщина', 'гей'],
#  ['часть', 'кульуры'],
#  ['это'],
#  ['би',
#   'большой',
#   'трап',
#   'понимать',
#   'челобесов',
#   'который',
#   'топить',
#   'свобода',
#   'ебли',
#   'жопа',
#   'культурный',
#   'марксизм'],
#  ['весь', 'могила', 'рыть', 'разрушать', 'западный', 'культура'],
#  ['квота',
#   'мигрант',
#   'грант',
#   'рождаемость',
#   'довести',
#   'всё',
#   'вымереть',
#   'остаться',
#   'циган',
#   'бедуин'],
#  ['наука',
#   'помогать',
#   'большой',
#   'молитвада',
#   'помогать',
#   'большой',
#   'отменять'],
#  ['путать', 'мракобесие', 'образованность'],
#  ['эллинизм',
#   'поздний',
#   'христианство',
#   'век',
#   'служить',
#   'база',
#   'цивилизованность',
#   'наука'],
#  ['среди',
#   'схоласт',
#   'учёный',
#   'изобретение',
#   'сделать',
#   'записать',
#   'монах',
#   'например',
#   'генетика',
#   'горох'],
#  ['атеист',
#   'геймер',
#   'воспитанный',
#   'игра',
#   'парадокс',
#   'никак',
#   'история',
#   'приходиться',
#   'становиться',
#   'реальный',
#   'культуролог',
#   'это',
#   'ваш',
#   'культурный',
#   'марксист'],
#  ['гордиться',
#   'свой',
#   'поколениемя',
#   'вроде',
#   'пять',
#   'год',
#   'старший',
#   'высокий',
#   'образование'],
#  ['понимать'],
#  ['поезд',
#   'который',
#   'нестись',
#   'собственный',
#   'боль',
#   'простой',
#   'вещь',
#   'понимать'],
#  ['либерал'],
#  ['свобода', 'человек', 'превыше', 'весь'],
#  ['каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'другимя',
#   'хотеть',
#   'убивать',
#   'весь',
#   'мигрант',
#   'пидорас',
#   'вредить',
#   'общество',
#   'соответственно',
#   'сделать',
#   'убить'],
#  ['мигрант',
#   'совершать',
#   'преступление',
#   'пидорас',
#   'совращать',
#   'несформировавшиеся',
#   'ум',
#   'ребёнок',
#   'просто',
#   'лить',
#   'дерьмо',
#   'ухо'],
#  ['левак', 'кстати'],
#  ['это', 'сказать'],
#  ['ахахазазахахехеухухихихиэхэхэхэохохохохойхй'],
#  ['окружающий', 'среда', 'похуй', 'жрать', 'срёшь'],
#  ['похуй', 'последствие', 'свой', 'деяние'],
#  ['ебать', 'тупой'],
#  ['жрать', 'мясо', 'производить', 'большой', 'мясо'],
#  ['влияние', 'окружающий', 'среда', 'например', 'корова', 'курс'],
#  ['ага'],
#  ['феминистический', 'движение', 'давно', 'равный', 'право'],
#  [],
#  ['поздравлять'],
#  ['ахмед',
#   'мультикультуралист',
#   'твой',
#   'убеждение',
#   'хотеть',
#   'отрезать',
#   'голова'],
#  ['плюс', 'путать', 'нетерпимость', 'раса', 'культура'],
#  ['нужно', 'ахмед'],
#  ['либерал', 'это', 'вообще', 'диагноз'],
#  ['рублёвый', 'дерьмо', 'вылезти'],
#  ['человек', 'наука', 'агностик'],
#  ['знать', 'бог'],
#  ['высрал', 'это'],
#  ['среди', 'учёный', 'веровать', 'атеист'],
#  ['нлрмисдрочу', 'расчленёнка', 'вряд', 'назвать', 'нормисом'],
#  ['вопрос', 'политический', 'принадлежность'],
#  ['очередной', 'промытышь', 'бляяяяя'],
#  ['пиздуй', 'отсюда', 'подстилка'],
#  ['фотография', 'предок', 'конец', 'начало', 'век'],
#  ['удивительно', 'всё', 'бела', 'высокий', 'иметь', 'черта', 'лицо', 'народ'],
#  ['женщина',
#   'принуждать',
#   'мужской',
#   'профессиямтипа',
#   'шахтёр',
#   'грузчик',
#   'жд',
#   'работник',
#   'дозиметрист'],
#  ['вред', 'здоровье', 'женщина', 'ребёнок', 'это', 'норма'],
#  ['выпадение', 'матка', 'прочее'],
#  ['убеждение', 'взгляд', 'наш', 'промыть', 'пыней', 'мозг', 'дэ'],
#  ['норма'],
#  ['терние', 'звезда', 'бесплатно', 'получиться'],
#  ['это',
#   'изнасилование',
#   'назвать',
#   'повториться',
#   'изнасилование',
#   'вред',
#   'здоровье',
#   'это',
#   'убийство',
#   'смерть',
#   'оксюморон'],
#  ['нихуя', 'жир', 'аж', 'потечь', 'экран', 'скрыть'],
#  ['агрессия', 'нацист', 'беспочвенный'],
#  ['дрочить', 'расчленёнка'],
#  ['националист'],
#  ['человек', 'социальный', 'существо', 'объединяться', 'группа'],
#  ['действовать',
#   'сообща',
#   'мочь',
#   'достигнуть',
#   'больший',
#   'вместе',
#   'формировать',
#   'общий',
#   'благополучие'],
#  ['ресурс',
#   'благополучие',
#   'ограничить',
#   'претендовать',
#   'группа',
#   'человек',
#   'поэтому',
#   'разумно',
#   'укреплять',
#   'взаимопонимание',
#   'единство',
#   'внутри',
#   'группа',
#   'который',
#   'относиться',
#   'вместе',
#   'пользоваться',
#   'совместный',
#   'труд',
#   'повышать',
#   'эффективность'],
#  ['мочь', 'осознать', 'макака', 'сравнение', 'действительно', 'серьёзный'],
#  ['интересоваться',
#   'теория',
#   'заговор',
#   'нахуй',
#   'поехать',
#   'большой',
#   'задумываться'],
#  ['нетсталкер'],
#  ['пытаться',
#   'игра',
#   'сознание',
#   'дабы',
#   'достигнуть',
#   'иной',
#   'видение',
#   'мир',
#   'траллируя',
#   'весь',
#   'просвященных',
#   'лсд',
#   'просто',
#   'ёбаный',
#   'обьебыши',
#   'итог'],
#  ['видеть',
#   'смерть',
#   'животное',
#   'вне',
#   'монитор',
#   'всё',
#   'твой',
#   'веганские',
#   'потуга',
#   'смешной'],
#  ['убивать',
#   'корова',
#   'исламоверующими',
#   'видеть',
#   'пытаться',
#   'ещё',
#   'предпринять'],
#  ['давать', 'её', 'ребёнок', 'закопать', 'мёртвый'],
#  ['сойбой', 'способный', 'вынести', 'тягота'],
#  ['декабрь', 'начаться', 'новый', 'эра'],
#  ['шизов', 'прочий', 'личность', 'нахуй', 'пойти', 'сдвиг'],
#  ['поверь', 'нечего', 'противопоставить'],
#  ['готовся'],
#  ['фотография', 'предок', 'вплоть', 'митохондриальный', 'ева'],
#  ['год',
#   'учиться',
#   'вуз',
#   'программиставсегда',
#   'считать',
#   'весь',
#   'программист',
#   'пидорас',
#   'иначе',
#   'объяснить',
#   'весь',
#   'софт',
#   'хуёвый',
#   'блядь'],
#  ['ещё', 'являться', 'школотой', 'максималист'],
#  ['иметь',
#   'место',
#   'секс',
#   'принуждение',
#   'использование',
#   'беспомощный',
#   'состояние',
#   'результат',
#   'приченено',
#   'вред',
#   'здоровье',
#   'изнасилование'],
#  ['делать'],
#  [],
#  [],
#  ['любой'],
#  ['жирно', 'смешно'],
#  ['переделывать'],
#  ['короче',
#   'это',
#   'жирнота',
#   'ёбаный',
#   'всё',
#   'дегенеративный',
#   'учение',
#   'верить',
#   'являться',
#   'гетеросексуалом',
#   'ор',
#   'довенов',
#   'ответить',
#   'тред',
#   'сасите',
#   'быдло',
#   'гои'],
#  [],
#  ['мендель', 'священник', 'монах'],
#  ['очень', 'разный', 'вещь'],
#  ['тред', 'хуйня'],
#  ['хуйня', 'тред', 'гетеросексуал'],
#  ['поверить'],
#  ['здоровый', 'веганстве'],
#  ['лола',
#   'хотеть',
#   'россия',
#   'проходить',
#   'лгбт',
#   'парадыкак',
#   'насчёт',
#   'парад',
#   'некрофил',
#   'педофил',
#   'зоофилов'],
#  ['женщина',
#   'абсолютный',
#   'равный',
#   'мужчинебиология',
#   'думать',
#   'иначе',
#   'русский',
#   'девушка',
#   'встречаться',
#   'кавказец',
#   'афроамериканец',
#   'это',
#   'прекрасно'],
#  ['ммммаксимум',
#   'шовинизм',
#   'лола',
#   'каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'другима',
#   'вредить',
#   'лгбт',
#   'пропаганда'],
#  ['покормить'],
#  ['являться', 'веганомдальше', 'читать'],
#  ['сажа', 'скрыть'],
#  ['обучить', 'великий'],
#  ['спасибо', 'информация'],
#  ['чур', 'чур', 'идти', 'нахуй', 'далёкий', 'чепушок'],
#  ['мимо',
#   'атеистолсо',
#   'русский',
#   'девушка',
#   'встречаться',
#   'кавказец',
#   'афроамериканцемпочему',
#   'кавказский',
#   'девушка',
#   'африканка',
#   'нация',
#   'нейм'],
#  ['мочь', 'отвечать', 'кук'],
#  ['секс',
#   'принуждение',
#   'использование',
#   'беспомощный',
#   'состояниявсё',
#   'это',
#   'нести',
#   'вред',
#   'ментальный',
#   'здоровье'],
#  ['подобрать', 'синоним', 'контекст', 'целибат'],
#  ['уклад'],
#  ['либерал', 'свобода', 'также', 'либерал', 'посодить', 'весь'],
#  ['сажать'],
#  ['хахах', 'пиздец', 'еблан'],
#  ['голос'],
#  ['насчёт', 'парад', 'некрофил', 'педофил', 'зоофилов'],
#  ['дать',
#   'пара',
#   'год',
#   'сжв',
#   'кукарекам',
#   'первый',
#   'поползновение',
#   'сторона'],
#  ['шконарь',
#   'калёный',
#   'железо',
#   'загнать',
#   'пара',
#   'год',
#   'увидеть',
#   'парад'],
#  ['корча', 'смешение', 'раскуколд'],
#  ['это', 'казаться', 'называться'],
#  ['уклад',
#   'мневообще',
#   'священник',
#   'это',
#   'фактически',
#   'мирянин',
#   'который',
#   'жить',
#   'церковь',
#   'выполнять',
#   'обрядовый',
#   'функция'],
#  ['ебёт',
#   'жена',
#   'общаться',
#   'друг',
#   'вкусно',
#   'жирно',
#   'кушать',
#   'ездить',
#   'отпуск'],
#  ['монах',
#   'уходить',
#   'лес',
#   'жить',
#   'питаться',
#   'сухой',
#   'коренья',
#   'пиздит',
#   'плеть',
#   'тд'],
#  ['около'],
#  ['всё',
#   'это',
#   'нести',
#   'вред',
#   'ментальный',
#   'здоровье',
#   'особенно',
#   'случай',
#   'шкура',
#   'просто',
#   'напиться',
#   'отдаться',
#   'компашка',
#   'вписка',
#   'лола'],
#  ['видосик', 'глупость', 'слить', 'сеть', 'узнать'],
#  ['писать', 'заяву', 'износ'],
#  ['история', 'старый', 'мир', 'камера', 'телефон'],
#  ['пара', 'год', 'увидеть', 'парад'],
#  ['дать', 'бог', 'дать', 'бог'],
#  ['забор', 'википедия', 'написать', 'год', 'монах'],
#  ['мендель'],
#  ['всё', 'священник', 'монах'],
#  ['сасать'],
#  ['достопочтенный', 'господин', 'пояснить'],
#  ['атеист'],
#  ['патриот'],
#  ['любовь', 'гордость', 'либо', 'страна', 'испытывать'],
#  ['ненависть', 'испытывать', 'страна', 'который', 'жить', 'страна'],
#  ['избегать',
#   'исламистких',
#   'страна',
#   'путешествовать',
#   'считать',
#   'мусульманин',
#   'агрессивный',
#   'знать',
#   'ожидать'],
#  ['мочь',
#   'испытывать',
#   'гордость',
#   'достижение',
#   'наука',
#   'независимо',
#   'страна',
#   'учёный'],
#  ['лгбт', 'относиться', 'также', 'гетеросексуалам'],
#  ['против', 'парад'],
#  [],
#  ['обычно', 'весело', 'проходить', 'штат'],
#  ['гетеросексуал'],
#  ['торонник', 'равный', 'право', 'женщина', 'мужчина'],
#  ['дать', 'бог', 'дать', 'бог', 'пойти', 'хуй'],
#  ['шкура',
#   'просто',
#   'напиться',
#   'отдаться',
#   'компашка',
#   'впискетакое',
#   'одобрять',
#   'её',
#   'выбор',
#   'видосик',
#   'глупость',
#   'слить',
#   'сетьа',
#   'это',
#   'противозаконно',
#   'нести',
#   'вред',
#   'её',
#   'частный',
#   'собственность',
#   'здоровье'],
#  ['далбаеб'],
#  ['перестать', 'толстить', 'серьёзно'],
#  ['ама', 'всё', 'священник', 'монах'],
#  ['протестант'],
#  ['ебанулся'],
#  ['идти', 'спать'],
#  ['википедия', 'википедия', 'мочь', 'написать', 'очко', 'ебали'],
#  ['год',
#   'мендель',
#   'постричься',
#   'монах',
#   'августинский',
#   'монастырь',
#   'святой',
#   'фома',
#   'брюнне',
#   'ныне',
#   'брно',
#   'чехия',
#   'взять',
#   'имя',
#   'грегор'],
#  ['гей', 'куколдом'],
#  ['выйти',
#   'свой',
#   'жена',
#   'загс',
#   'сразу',
#   'побежать',
#   'класть',
#   'её',
#   'первый',
#   'попасться',
#   'армянин'],
#  ['советовать', 'поступать', 'это', 'будущее', 'прогресс'],
#  ['ебать', 'толсто'],
#  ['похуй'],
#  ['декабрь', 'днюха', 'хуйня', 'это', 'особый', 'число', 'че', 'буит'],
#  ['мимо', 'завсегдатый', 'последний', 'время', 'сиэтл', 'отойти', 'движуха'],
#  ['экран', 'потечь'],
#  ['спрашивать', 'достопочтенный', 'господин'],
#  ['это', 'сформироваться', 'взглядынет'],
#  ['чипированный', 'съеби', 'любой', 'нелюдь'],
#  ['долбоёб', 'нужно', 'сажи', 'въебать'],
#  ['теория',
#   'заговор',
#   'сталкер',
#   'лсд',
#   'объебосы',
#   'декабрь',
#   'новый',
#   'эра',
#   'готовся',
#   'игра',
#   'сознаниемебать',
#   'знать',
#   'больший',
#   'толстяк',
#   'оп'],
#  ['посоны', 'мочь', 'просто', 'меч', 'попиздимся', 'нахуй', 'левак'],
#  ['всё', 'анархия', 'фашизм'],
#  ['никакой', 'свобода', 'враг', 'свобода'],
#  ['двачую'],
#  ['прогромист', 'наверно'],
#  ['фашист', 'левак', 'тред', 'спок'],
#  ['почему', 'всё', 'гей', 'истеричка'],
#  ['программистакакой', 'язык', 'любимый'],
#  ['прийти', 'власть', 'отрезать', 'голова', 'лола'],
#  ['скрыть', 'бототред'],
#  ['кек'],
#  ['жопа'],
#  ['охуенно', 'потусить', 'прайд', 'кунчиком', 'симпатичный', 'сьюте'],
#  ['который',
#   'твой',
#   'девушка',
#   'ногя',
#   'кайф',
#   'доставлять',
#   'ловить',
#   'множественный',
#   'оргазм'],
#  ['жена', 'это', 'выебешь'],
#  ['умолять'],
#  ['думать', 'пробовать'],
#  ['жить',
#   'ебучей',
#   'пидорашки',
#   'норма',
#   'страна',
#   'человек',
#   'давно',
#   'лгбт',
#   'парад',
#   'наслаждаться',
#   'говно'],
#  ['откуда', 'уверенный', 'это', 'человек'],
#  ['оп', 'пробовать', 'тонкий', 'нихуя', 'правдоподобно'],
#  ['пох', 'оп', 'признаться', 'жирный', 'поговорить', 'паста'],
#  ['хотеть',
#   'причинять',
#   'вред',
#   'животнымне',
#   'существовать',
#   'вред',
#   'животное'],
#  ['либо',
#   'разделять',
#   'весь',
#   'человек',
#   'нечеловек',
#   'либо',
#   'жалеть',
#   'каждый',
#   'молекула',
#   'каждый',
#   'бактерия'],
#  ['животное',
#   'мочь',
#   'мыслить',
#   'чувствовать',
#   'боль',
#   'лишь',
#   'зов',
#   'подмога'],
#  ['любой',
#   'иной',
#   'подход',
#   'лицемерие',
#   'человек',
#   'решать',
#   'проводить',
#   'граница',
#   'меж',
#   'значимый',
#   'незначимый'],
#  ['комар', 'убить', 'это', 'норма', 'бык', 'грех'],
#  ['почему',
#   'пофиг',
#   'человек',
#   'заниматься',
#   'спальня',
#   'блэт',
#   'отправить',
#   'спальня'],
#  ['гей',
#   'значительно',
#   'плохой',
#   'физический',
#   'здоровье',
#   'транс',
#   'психика',
#   'говорить',
#   'приходиться'],
#  ['разрешать',
#   'пропаганда',
#   'это',
#   'это',
#   'фактически',
#   'равнозначный',
#   'погружение',
#   'ребёнок',
#   'размышление',
#   'уровень',
#   'стата',
#   'суицидников',
#   'сто',
#   'выше'],
#  ['женщина', 'абсолютный', 'равный', 'мужчинену', 'скажем', 'рф', 'равный'],
#  ['вообще',
#   'нисколько',
#   'равный',
#   'женщина',
#   'слабый',
#   'физически',
#   'обуславливать',
#   'определённый',
#   'статья',
#   'трудовой',
#   'кодекс',
#   'аналог',
#   'женщина',
#   'мочь',
#   'уйти',
#   'рожать',
#   'вообще',
#   'отдельный',
#   'тема',
#   'разговор'],
#  ['игнорить',
#   'факт',
#   'особенно',
#   'последний',
#   'просто',
#   'невозможно',
#   'фемки',
#   'почему',
#   'свой',
#   'речь',
#   'делать',
#   'вид',
#   'это',
#   'нечто',
#   'незначимый',
#   'недостойный',
#   'упоминание',
#   'речь',
#   'идти',
#   'равенство',
#   'пол'],
#  ['расист', 'этоэто', 'личный', 'опыт'],
#  ['жить', 'маленький'],
#  ['житель',
#   'городок',
#   'помнить',
#   'всё',
#   'кавказец',
#   'цыган',
#   'прочий',
#   'ребята',
#   'это',
#   'основной',
#   'источник',
#   'наркота',
#   'целое',
#   'мелкий',
#   'криминал'],
#  ['отдельно',
#   'взять',
#   'человек',
#   'относиться',
#   'репутация',
#   'свойственный',
#   'человек',
#   'социальный',
#   'группа',
#   'весь',
#   'вытекать',
#   'последствие'],
#  ['выебу'],
#  ['жена', 'сестра', 'мамаша', 'твой'],
#  ['оп',
#   'написать',
#   'пост',
#   'который',
#   'ответить',
#   'комментировать',
#   'свой',
#   'пост'],
#  ['вообще', 'весь', 'двое'],
#  ['любить',
#   'зог',
#   'почитать',
#   'крамола',
#   'ютубе',
#   'посмотреть',
#   'прям',
#   'угарать',
#   'почему',
#   'уверенный',
#   'весь',
#   'тред',
#   'написать',
#   'человек'],
#  ['пока', 'учиться'],
#  ['блядь', 'написать', 'человек'],
#  ['вносить', 'неразбериха', 'монолог'],
#  ['год', 'дело', 'говноед'],
#  ['пофиксилвкусный', 'порридж', 'ами', 'какульками', 'зумерок'],
#  ['думать', 'средневековый', 'бой', 'записаться', 'охуенный', 'тема'],
#  ['благо', 'москва', 'выбрать'],
#  ['жена', 'сестра', 'мамаша', 'твоюспасибо', 'огромный'],
#  ['ждать', 'нетерпение', 'просьба', 'небольшой'],
#  ['мочь',
#   'жена',
#   'ебать',
#   'вытащить',
#   'хуй',
#   'кончить',
#   'лицо',
#   'харкнуть',
#   'сапог',
#   'ебальник',
#   'дать'],
#  ['дебил'],
#  ['существовать', 'вообще'],
#  ['фашист', 'государство', 'дрочить', 'анархист'],
#  ['кстати', 'новый', 'клип', 'лсп'],
#  ['фреймворк', 'алгоритм', 'учить', 'долбоеб'],
#  ['хуйня', 'страдать'],
#  ['ох', 'ебать', 'жирнота'],
#  ['либертарианец'],
#  ['веган',
#   'плевать',
#   'окружающий',
#   'среда',
#   'хотеть',
#   'причинять',
#   'вред',
#   'животное'],
#  ['здоровый', 'веганстве'],
#  ['животное'],
#  ['обязать', 'мясо', 'это', 'вид', 'животное'],
#  ['заставлять', 'домашний', 'животное'],
#  ['свой', 'веганством', 'причинять', 'вред', 'растение'],
#  ['лгбт', 'гей', 'бишки', 'всё', 'небинарные', 'это', 'зайка'],
#  ['любить', 'любой', 'проявление', 'гейства'],
#  ['это', 'личный', 'выбор', 'каждый'],
#  ['хотеть', 'россия', 'проходить', 'лгбт', 'парад'],
#  ['би', 'сексуал'],
#  ['почему', 'пофиг', 'человек', 'заниматься', 'спальнесам', 'грех'],
#  ['блядь',
#   'гендер',
#   'поддерживать',
#   'феминизм',
#   'женщина',
#   'абсолютный',
#   'равный',
#   'мужчина'],
#  ['век', 'женщина', 'угнетать', 'продолжать', 'сей', 'пора'],
#  ['право',
#   'женщина',
#   'нужно',
#   'уравнять',
#   'появиться',
#   'женщина',
#   'учёный',
#   'писатель',
#   'инженер',
#   'который',
#   'ранний',
#   'давить'],
#  ['женщина',
#   'изменить',
#   'парень',
#   'муж',
#   'это',
#   'её',
#   'дело',
#   'абортво',
#   'первый',
#   'это',
#   'актуально',
#   'россия'],
#  ['домашний', 'насилие', 'страдать', 'пол'],
#  ['второй',
#   'малолетний',
#   'дебил',
#   'женщина',
#   'никто',
#   'давить',
#   'кюри',
#   'цветаев',
#   'ебливые',
#   'художница',
#   'х',
#   'жанр',
#   'супрематизм'],
#  ['руководящий', 'должность', 'женщина'],
#  ['блядь'],
#  ['третий', 'равноправие', 'пол', 'абсолютный', 'матриархат', 'отношение'],
#  ['идиот'],
#  ['аборт', 'измена', 'оба', 'сторона', 'это', 'дело', 'оба', 'сторона'],
#  ['решать', 'позиция'],
#  ['выписать', 'движа'],
#  ['феминист'],
#  ['просто', 'союзник', 'лола', 'мудьтикультаралист'],
#  ['расист', 'это', 'наклеить', 'наклейка', 'надпись', 'идиот'],
#  ['наука', 'давно', 'опровергнуть', 'всё', 'положение', 'расизм'],
#  ['человек', 'должный', 'всё', 'перемешаться', 'раса', 'таковой'],
#  ['всё', 'здоровый', 'счастливый'],
#  ['русский',
#   'девушка',
#   'встречаться',
#   'кавказец',
#   'афроамериканец',
#   'это',
#   'прекрасно'],
#  ['это', 'вообще', 'фиаско'],
#  ['раса', 'различие'],
#  ['отрицание', 'это', 'глупость'],
#  ['каждый', 'раса', 'свой', 'сильный', 'слабый', 'сторона'],
#  ['организм', 'приспосабливаться', 'местность', 'бла', 'бла'],
#  ['русский', 'семья', 'также', 'кавказка', 'позор', 'встречаться', 'ребёнок'],
#  ['отношение', 'выйти', 'нечего'],
#  ['конец', 'девка', 'сбежать', 'обычай', 'гнёт', 'родитель', 'парень'],
#  ['негр', 'лёгкий', 'свой', 'подводный'],
#  ['сажать'],
#  ['это', 'всё', 'шутка', 'либерал'],
#  ['свобода', 'человек', 'превыше', 'весь'],
#  ['каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'другимты',
#   'либерал'],
#  ['который', 'плевать', 'свобода'],
#  ['мат', 'часть', 'привыше', 'также', 'научный', 'атеист'],
#  ['религия', 'это', 'яд', 'никакой', 'бог'],
#  ['наука',
#   'помогать',
#   'большой',
#   'молитвау',
#   'религия',
#   'это',
#   'слепой',
#   'вера',
#   'наука'],
#  ['вообще'],
#  ['слишком', 'толстый', 'троллинг'],
#  ['нулевой', 'пост'],
#  ['это', 'плохой'],
#  ['почему',
#   'пофиг',
#   'человек',
#   'заниматься',
#   'спальня',
#   'дело',
#   'весь',
#   'пофиг',
#   'пока',
#   'это',
#   'спальня',
#   'центральный',
#   'улица'],
#  ['каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'человек',
#   'должный',
#   'всё',
#   'перемешаться',
#   'раса',
#   'таковыхнахуй',
#   'сходить',
#   'никто',
#   'должный'],
#  ['наука', 'помогать', 'большой', 'молитваиди', 'матешу', 'делать'],
#  ['неимоверный',
#   'толщина',
#   'вброс',
#   'пропустить',
#   'постовдвач',
#   'двач',
#   'меняться'],
#  ['жирно'],
#  ['анархист',
#   'нацист',
#   'должный',
#   'сидеть',
#   'тюрьма',
#   'хейтспичеры',
#   'должный',
#   'сидеть',
#   'тюрьма',
#   'вообще',
#   'всё',
#   'нравиться',
#   'должный',
#   'сидеть',
#   'тюрьма'],
#  ['дело',
#   'сеть',
#   'блядь',
#   'государство',
#   'ёбаный',
#   'просто',
#   'страйкбол',
#   'играть',
#   'защооооо'],
#  ['поговорить', 'копипаста', 'традиция', 'двача', 'хула'],
#  ['государство', 'нужно'],
#  ['двачую'],
#  ['чечня', 'стесняться', 'свой', 'гей', 'жёстко', 'пиздит'],
#  ['бояться', 'подумать', 'гей'],
#  ['паста', 'форча'],
#  ['либерал'],
#  ['свобода', 'человек', 'превыше', 'весь'],
#  ['каждый',
#   'мочь',
#   'делать',
#   'захотеть',
#   'это',
#   'вредить',
#   'расист',
#   'это',
#   'наклеить',
#   'наклейка',
#   'надпись',
#   'идиот',
#   'религия',
#   'это',
#   'яд',
#   'никакой',
#   'бог'],
#  ['наука', 'помогать', 'большой', 'молитва'],
#  ['человек',
#   'нужный',
#   'животный',
#   'пища',
#   'белка',
#   'аминокислота',
#   'получать',
#   'мучение',
#   'животное',
#   'креатин',
#   'синтезироваться',
#   'лабораторияхесли',
#   'гендер',
#   'определяться',
#   'человек',
#   'мочь',
#   'бесчисленный',
#   'множество',
#   'дело',
#   'принуждать',
#   'это',
#   'соглашаться',
#   'очевидный',
#   'получиться',
#   'речь',
#   'гос'],
#  ['структура', 'получение', 'паспорт', 'прочее'],
#  ['хороший', 'традиция'],
#  ['пизди', 'залупу', 'выдумать'],
#  ['жирнота', 'спалилась'],
#  ['веган',
#   'плевать',
#   'окружающий',
#   'среда',
#   'хотеть',
#   'причинять',
#   'вред',
#   'животное'],
#  ['смерть',
#   'хороший',
#   'мочь',
#   'случиться',
#   'животное',
#   'который',
#   'разводить',
#   'еда'],
#  ['хотеть',
#   'россия',
#   'проходить',
#   'лгбт',
#   'парад',
#   'почему',
#   'пофиг',
#   'человек',
#   'заниматься',
#   'спальнепусть',
#   'проводить',
#   'спальня',
#   'парад'],
#  ['право',
#   'женщина',
#   'нужно',
#   'уравнятьвысшей',
#   'мера',
#   'особо',
#   'тяжёлый',
#   'работа',
#   'армия',
#   'ходить'],
#  ['всё', 'довольно', 'ровно'],
#  ['м'],
#  ['извинить',
#   'погорячиться',
#   'надеяться',
#   'плоский',
#   'земля',
#   'верить',
#   'знать',
#   'знаменитость',
#   'ребёнок',
#   'молодость',
#   'сберечь'],
#  ['похуй', 'мучение', 'животное'],
#  ['заебошили', 'мочь'],
#  ['гендер', 'насрать', 'ибо', 'пол'],
#  ['считать', 'лечить', 'остальной', 'псих'],
#  ['поймать', 'рука', 'дешёвка'],
#  ['хотеть',
#   'россия',
#   'проходить',
#   'лгбт',
#   'парад',
#   'почему',
#   'пофиг',
#   'человек',
#   'заниматься',
#   'спальня',
#   'женщина',
#   'абсолютный',
#   'равный',
#   'мужчинекак',
#   'это',
#   'наука',
#   'давно',
#   'опровергнуть'],
#  ['именно', 'право', 'мужчина', 'сильно', 'маленький'],
#  ['точка', 'зрение', 'закон'],
#  ['либерал'],
#  ['свобода',
#   'человек',
#   'превыше',
#   'весь',
#   'религия',
#   'это',
#   'яд',
#   'никакой',
#   'бог'],
#  ['почему', 'взаимоисключащих', 'параграф'],
#  ['гендер',
#   'определяться',
#   'человек',
#   'мочь',
#   'бесчисленный',
#   'множествонахуй',
#   'нужный'],
#  ['ощущать', 'свирт', 'единорог'],
#  ['это', 'измениться', 'факт', 'рождение', 'пизда', 'хуй'],
#  ['наличие', 'хромосома', 'твой', 'днк'],
#  ['гомодрил',
#   'всё',
#   'надеяться',
#   'подхватить',
# ...
#   'газ',
#   'вег',
#   'сэкономить',
#   'свой',
#   'героический',
#   'подвиг',
#   'отказ',
#   'мясной',
#   'еда'],
#  ['весь', 'похуй'],
#  ['обсуждать',
#   'твой',
#   'высер',
#   'ибо',
#   'сорт',
#   'оф',
#   'актуально',
#   'похуй',
#   'искренне',
#   'это',
#   'написать',
#   'вообще',
#   'это',
#   'паста'],
#  ['перестать', 'жрать'],
#  ['пох', 'поспорить', 'спорщик', 'паста', 'существовать', 'вред', 'животное'],
#  ['комар', 'бык', 'сравнить'],
#  ['курс', 'это', 'называться', 'доведение', 'абсурд'],
#  ['давно', 'оправдывать', 'угнетение', 'женщина', 'негр'],
#  ['человек', 'лола'],
#  ['бросить',
#   'это',
#   'лицемерие',
#   'признать',
#   'высокий',
#   'животное',
#   'испытывать',
#   'эмоция',
#   'жрать',
#   'этично'],
#  ['пропаганда', 'ребёнок'],
#  ['старый', 'мир'],
#  ['защита', 'ребёнок', 'оправдать', 'любой', 'мерзость'],
#  ['пропагандировать'],
#  ['чувак', 'флаг', 'прям', 'мешать'],
#  ['алсо',
#   'пропаганда',
#   'сделать',
#   'ребёнок',
#   'гей',
#   'пропгандой',
#   'гей',
#   'сделать',
#   'гетеро'],
#  ['устрой', 'гетеропарад', 'пропагандировать', 'здоровье'],
#  ['чета',
#   'слышать',
#   'фемки',
#   'отрицать',
#   'биология',
#   'допускать',
#   'среди',
#   'упоротые'],
#  ['фемки',
#   'борятся',
#   'равенство',
#   'возможность',
#   'против',
#   'насилие',
#   'вощем',
#   'это',
#   'правильно'],
#  ['кавказец',
#   'лень',
#   'спорить',
#   'просто',
#   'вешать',
#   'ярлык',
#   'весь',
#   'основание',
#   'ограниченный',
#   'личный',
#   'опыт'],
#  ['постмодерне', 'жить', 'хула'],
#  ['лахта', 'толстить', 'дико', 'улыбнуло'],
#  ['ради', 'шматал', 'сало', 'говно', 'жирный', 'сага', 'оставить'],
#  ['название', 'игра', 'моника'],
#  ['помнить',
#   'целый',
#   'день',
#   'рубать',
#   'умирать',
#   'разбиваться',
#   'камень',
#   'давать',
#   'сначала'],
#  ['дать',
#   'ссылка',
#   'браузерку',
#   'помнить',
#   'ток',
#   'сайт',
#   'сайт',
#   'вспомнить'],
#  ['жирный', 'уйти'],
#  ['ясно', 'говно', 'лопата', 'активист'],
#  ['лгбт'],
#  ['точка'],
#  ['это', 'самый', 'жирный', 'хуйня', 'который', 'видеть', 'последний', 'год'],
#  ['поддерживать', 'феминизм', 'бороться', 'б', 'призыв', 'женщина', 'армия'],
#  ['мультикультуралист',
#   'готовый',
#   'маг',
#   'отпиздит',
#   'поддержка',
#   'лгбт',
#   'принять',
#   'поддерживать',
#   'культура'],
#  ['спасибомне', 'приятно'],
#  ['принудить',
#   'скажем',
#   'встать',
#   'колено',
#   'отсосать',
#   'бить',
#   'это',
#   'пойти',
#   'психиатр',
#   'выявить',
#   'психический',
#   'нарушение',
#   'изнасилование',
#   'претензия'],
#  ['пойти',
#   'психиатр',
#   'выявить',
#   'психический',
#   'нарушенийхуёвый',
#   'психиатр'],
#  ['комар', 'бык', 'сравнить'],
#  ['сравнить', 'скажем', 'таракан', 'куница'],
#  ['шуба', 'жалко', 'второй', 'гад', 'поганый', 'затоптать'],
#  ['насколько', 'близкий', 'сходство'],
#  ['всё',
#   'веганы',
#   'выбирать',
#   'проводить',
#   'черта',
#   'рыба',
#   'жалеть',
#   'намного',
#   'далёкий',
#   'человек',
#   'всякий',
#   'курица'],
#  ['защита', 'ребёнок', 'оправдать', 'любой', 'мерзостьи'],
#  ['конкретно', 'сказать'],
#  ['мб', 'напиздел'],
#  ['указать'],
#  ['твой', 'аппеляция', 'валидна'],
#  ['алсо',
#   'пропаганда',
#   'сделать',
#   'ребёнок',
#   'гей',
#   'пропгандой',
#   'гей',
#   'сделать',
#   'гетеро'],
#  ['устрой', 'гетеропарад', 'пропагандировать', 'здоровье'],
#  ['панимаешь', 'ребёнок', 'подадуться', 'пропаганда', 'это'],
#  ['пропаганда',
#   'также',
#   'подействовать',
#   'получить',
#   'ребёнок',
#   'который',
#   'больший',
#   'часть',
#   'скинуться',
#   'окно'],
#  ['речь',
#   'слово',
#   'парад',
#   'скорее',
#   'всякий',
#   'лекция',
#   'передача',
#   'телеканал'],
#  ['п'],
#  ['чета',
#   'слышать',
#   'фемки',
#   'отрицать',
#   'биологиюих',
#   'основной',
#   'постулат',
#   'женщина',
#   'равный',
#   'мужчина'],
#  ['повториться',
#   'равный',
#   'бе',
#   'равный',
#   'забывать',
#   'роды',
#   'коэф',
#   'распределение',
#   'мышечный',
#   'жировой',
#   'ткань'],
#  ['это',
#   'лицемерие',
#   'который',
#   'типо',
#   'учитываться',
#   'результат',
#   'хотеть',
#   'равный',
#   'право',
#   'равный',
#   'право',
#   'поправка',
#   'свой',
#   'недостаток',
#   'трактовка',
#   'роды',
#   'прочее',
#   'свой',
#   'сторона'],
#  ['кавказец',
#   'лень',
#   'споритьа',
#   'лениться',
#   'курить',
#   'стату',
#   'преступление',
#   'раса'],
#  ['поздно', 'оправдываться'],
#  ['ясно', 'пидорас', 'желать', 'умереть', 'рак', 'анус'],
#  ['жиденький', 'нахуй'],
#  ['доказать', 'свой', 'тезис'],
#  ['шарить',
#   'сжв',
#   'самый',
#   'ярый',
#   'педоистерички',
#   'зоошиза',
#   'секс',
#   'животное',
#   'считаться',
#   'жестокий',
#   'обращение'],
#  ['очень', 'толсто', 'реально', 'стать', 'горячо', 'задний', 'проход'],
#  ['позёр', 'ёбаный'],
#  ['программист', 'фурриеб'],
#  ['очень', 'жирно', 'идти', 'нахуй'],
#  ['год', 'давно', 'работать', 'программист'],
#  ['против', 'лгбт', 'всё', 'лгбт', 'персона', 'психически', 'больной'],
#  ['бороться',
#   'культурный',
#   'марксизм',
#   'вырабатывать',
#   'идея',
#   'законопроект',
#   'высылать',
#   'депутат'],
#  ['поддерживать',
#   'феминизм',
#   'женщина',
#   'абсолютно',
#   'равный',
#   'мужчина',
#   'всё',
#   'остальной',
#   'напридумывать',
#   'левак'],
#  ['против',
#   'мультикультурализма',
#   'хотеть',
#   'рядом',
#   'жить',
#   'носитель',
#   'отличаться',
#   'культура'],
#  ['православный', 'спасение', 'душа', 'превыше', 'весь'],
#  ['каждый', 'мочь', 'делать', 'учить', 'бог'],
#  ['научный',
#   'атеизм',
#   'агностицизм',
#   'это',
#   'яд',
#   'учёный',
#   'придумать',
#   'атомный',
#   'бомба',
#   'средство',
#   'массовый',
#   'поражение'],
#  ['научный',
#   'атеист',
#   'менее',
#   'мочь',
#   'называть',
#   'профессор',
#   'физика',
#   'больший',
#   'опыт',
#   'всё',
#   'остальной',
#   'веровать',
#   'наука'],
#  ['ваш',
#   'поколение',
#   'разложить',
#   'растленный',
#   'акула',
#   'бизнес',
#   'эгоистичный',
#   'обезьяна',
#   'понимать',
#   'хотеть',
#   'понимать',
#   'метафизика',
#   'который',
#   'прекрасный',
#   'свести',
#   'просмотр',
#   'ролик',
#   'ютуб',
#   'свобода',
#   'являться',
#   'лишь',
#   'возможность',
#   'безнаказанно',
#   'совершать',
#   'грех'],
#  ['повезти', 'суд', 'опираться', 'мнение'],
#  ['претензия'],
#  ['ладный', 'понравиться', 'вон', 'причмокивать'],
#  ['написать', 'би'],
#  ['хотеть', 'сосать', 'хуй'],
#  ['невозможно', 'изнасиловать', 'мужчина', 'согласие'],
#  ['батя', 'прорвать', 'язва'],
#  ['весь', 'жизнь', 'питаться', 'бухло', 'чипсы', 'жареный', 'картошка'],
#  ['вместо', 'вода', 'пить', 'либо', 'кола', 'либо', 'напиток'],
#  ['выписать',
#   'полтора',
#   'неделя',
#   'назад',
#   'сказать',
#   'диета',
#   'соблюдать',
#   'ибо',
#   'желудок',
#   'пизда',
#   'слизистый',
#   'атрофироваться',
#   'полностью',
#   'удивительно',
#   'рак'],
#  ['продолжать',
#   'пить',
#   'напиток',
#   'питаться',
#   'всякий',
#   'диета',
#   'вообще',
#   'поубавить',
#   'прям',
#   'никак',
#   'похуй'],
#  ['говорить', 'это', 'хуйня', 'всё', 'мужык', 'должный', 'всё'],
#  ['лежать',
#   'орать',
#   'хуёво',
#   'тошнить',
#   'болеть',
#   'утром',
#   'проблевался',
#   'сие'],
#  ['долбаеб'],
#  ['понимать', 'мочь', 'умереть'],
#  ['кончить'],
#  ['слушать',
#   'вообще',
#   'никак',
#   'драка',
#   'ругаться',
#   'пытаться',
#   'вдолбить',
#   'долбаебу'],
#  ['скоро', 'умереть', 'проблема'],
#  ['врач', 'рашке', 'долбоебы'],
#  ['европке', 'язва', 'давно', 'антибиотик', 'лечить'],
#  ['мордоре', 'продолжать', 'супчик', 'прописывать'],
#  ['вообще',
#   'нихуя',
#   'нормальный',
#   'еда',
#   'вообще',
#   'ноль',
#   'нахуй',
#   'жареный',
#   'мучной',
#   'острый',
#   'полуфабрикат',
#   'кекчупы'],
#  ['вода',
#   'пить',
#   'вообще',
#   'вообще',
#   'вообще',
#   'помнить',
#   'последний',
#   'пить',
#   'вода',
#   'таблетка',
#   'запивать',
#   'черри',
#   'хуйня',
#   'сладкий'],
#  ['хотеть', 'умирать'],
#  ['отвести', 'частный', 'клиника'],
#  ['нахуй', 'н', 'далёкий', 'жрать', 'реально', 'становиться', 'хуёво'],
#  ['долбаеба', 'могила', 'исправить'],
#  ['плохо', 'еда', 'продолжпншь', 'жрать', 'страдать', 'дигноз', 'очевидный'],
#  ['никак', 'жизнь', 'реализовать'],
#  ['это', 'стандартный', 'поведение', 'человек'],
#  ['либо',
#   'выливать',
#   'всё',
#   'недовольство',
#   'либо',
#   'начинаться',
#   'деструктивный',
#   'поведение',
#   'число',
#   'жраньё',
#   'чипсы',
#   'пила',
#   'лола',
#   'который',
#   'пациент',
#   'наказываться',
#   'тип',
#   'становиться',
#   'лёгкий',
#   'это'],
#  ['сожаление',
#   'твой',
#   'батя',
#   'откровенно',
#   'тупойа',
#   'тупой',
#   'действовать',
#   'естесственный',
#   'отборникаких',
#   'случайность',
#   'жизненный',
#   'несправедливостейздесь',
#   'всё',
#   'максимально',
#   'закономерно',
#   'логично'],
#  ['мочь', 'удержаться', 'хз'],
#  ['мочь', 'жрать', 'вредный', 'еда'],
#  ['твой',
#   'нормальный',
#   'еда',
#   'жареный',
#   'мучной',
#   'полуфабрикат',
#   'это',
#   'нормальный',
#   'еда'],
#  ['привести', 'пример', 'разнообразный', 'диета', 'каша', 'супчик'],
#  ['варёный', 'картошка', 'мясо'],
#  ['варёный', 'яйцо'],
#  ['понимать',
#   'лёгкий',
#   'это',
#   'становиться',
#   'любить',
#   'добрый',
#   'достаточно',
#   'конфликтный',
#   'вообще',
#   'тупой'],
#  ['гречка', 'котлетамия', 'устать', 'писать'],
#  ['хотя', 'заменить', 'жареный', 'мясо', 'печёный', 'духовка', 'варёный'],
#  ['батя',
#   'естественный',
#   'отбор',
#   'распространяться',
#   'оипрысок',
#   'лицо',
#   'опхуя'],
#  ['хотя', 'желательно', 'тест', 'отцовство', 'сделать'],
#  ['долбоёб'],
#  ['клинический',
#   'рекомендация',
#   'язва',
#   'открыть',
#   'кукарекать',
#   'либераха',
#   'малолетний'],
#  ['учить', 'батя', 'жить'],
#  ['хотеть', 'сдохнуть', 'пусть', 'дохнуть'],
#  ['иметь', 'ввиду', 'точно'],
#  ['атрофический', 'гастрит', 'кровоточить', 'язва', 'каша', 'супчик'],
#  ['серебряный', 'волокова', 'студия'],
#  ['блядь', 'анон'],
#  ['двачи', 'заходить', 'расстраиваться'],
#  ['давить', 'родственник', 'человек', 'который', 'уважать'],
#  ['сказать', 'вон', 'путин', 'здоровый', 'гавно'],
#  ['крепиться', 'хула'],
#  ['зато',
#   'нипидараха',
#   'питаться',
#   'хочит',
#   'ниташт',
#   'быдло',
#   'супчик',
#   'кашой'],
#  ['человек',
#   'дырка',
#   'стенка',
#   'желудок',
#   'выебываться',
#   'умничать',
#   'тип',
#   'показать',
#   'нормальный',
#   'разнообразный',
#   'диета',
#   'приходиться'],
#  ['жрать',
#   'положить',
#   'хотеть',
#   'чипсы',
#   'высыпаться',
#   'желудок',
#   'брюшной',
#   'полость'],
#  ['долбаеб'],
#  ['батя', 'твой'],
#  ['понимать', 'мочь', 'умереть'],
#  [],
#  ['кончить'],
#  [],
#  ['попробовать', 'провести', 'последний', 'год', 'жизнь', 'любить'],
#  ['батька', 'изменить'],
#  ['анон', 'решение'],
#  ['готовить'],
#  ['это', 'звать', 'папа', 'покушать', 'сделать', 'давать', 'подваливать'],
#  ['вместе'],
#  ['месяц',
#   'выработаться',
#   'новый',
#   'пищевой',
#   'привычка',
#   'сидеть',
#   'время',
#   'еда'],
#  ['мочь', 'спасти', 'папа'],
#  ['выбрать', 'изощеренный', 'способ', 'суецыда'],
#  ['бургер', 'захавал', 'сегодня', 'чмоня'],
#  ['всё',
#   'диета',
#   'лечебный',
#   'мероприятие',
#   'должный',
#   'соответствовать',
#   'твой',
#   'маняфантазиям',
#   'разнообразие'],
#  ['пидорашьего', 'мнение', 'спрашивать'],
#  ['хуйня', 'мама', 'рассказывать', 'бабка', 'поликлиника'],
#  ['добавить'],
#  ['слушать', 'вообще', 'никаки', 'личный', 'пример', 'вовлечение', 'действие'],
#  ['пока', 'смочь'],
#  ['краска', 'кап', 'полный', 'говно'],
#  ['помойка'],
#  ['гетто', 'топ', 'нигер'],
#  ['мнение',
#   'часть',
#   'сумма',
#   'платить',
#   'надпись',
#   'маршал',
#   'фирма',
#   'который',
#   'давно',
#   'сконцентрировать',
#   'производство',
#   'наушник'],
#  ['мимо'],
#  ['владелец', 'айкоса'],
#  ['че', 'хуйня', 'страна', 'стики', 'хитс', 'называться'],
#  ['это',
#   'похожий',
#   'хуйня',
#   'который',
#   'весь',
#   'округ',
#   'пахнуть',
#   'пердежом'],
#  ['кб', 'найти'],
#  ['обычный', 'отличаться'],
#  ['скачать',
#   'активатор',
#   'минутный',
#   'дело',
#   'зато',
#   'играть',
#   'игор',
#   'смотреть',
#   'кинцо',
#   'анимцо',
#   'богомерской',
#   'плашка'],
#  ['пизди', 'мешать'],
#  ['охуеешь', 'мешать'],
#  ['сетап'],
#  ['думать', 'купить', 'второй', 'монитор', 'гц', 'хватать'],
#  ['блядь',
#   'нахуя',
#   'свой',
#   'фотка',
#   'сюда',
#   'лить',
#   'загружать',
#   'модем',
#   'блядь'],
#  ['засвет'],
#  ['старый', 'проводной'],
#  ['взгляд', 'очень', 'удачный'],
#  ['большой', 'нравиться', 'относительно', 'новый', 'макбуке'],
#  ['краска', 'кнопка', 'держаться', 'облезлый'],
#  ['айкосник', 'здарова'],
#  ['самый',
#   'хуёвый',
#   'матрица',
#   'рынок',
#   'гц',
#   'монитор',
#   'месяц',
#   'настраивать',
#   'цвет',
#   'выглядеть',
#   'богомерзкий',
#   'привыкнуть',
#   'вроде'],
#  ['опоздать', 'поезд', 'технология'],
#  ['засмеяться', 'обосрался', 'тредпостим', 'смешной'],
#  ['хуй', 'петушара'],
#  ['создалане', 'заготовить'],
#  [],
#  ['понять', 'оп', 'пикрил'],
#  ['пояснить', 'двач'],
#  ['держать'],
#  ['пидор', 'пытаться', 'бампать'],
#  ['написать', 'постим', 'смешноеу', 'смешной'],
#  ['швейный',
#   'фабрика',
#   'назвать',
#   'свой',
#   'модель',
#   'вещь',
#   'всякий',
#   'ебанутыми',
#   'название',
#   'уровень',
#   'тётя',
#   'сраки',
#   'тип',
#   'свитор',
#   'эстет',
#   'штаны',
#   'модник'],
#  ['пик', 'видимо', 'попытка', 'пост', 'ирония', 'школьник', 'тема'],
#  ['уебок', 'свой', 'таракан', 'вылезти'],
#  ['каждый', 'проигрывать', 'муравей', 'первый'],
#  ['спасибо', 'анон'],
#  ['абу', 'благословить', 'пост'],
#  ['семён', 'заметный'],
#  ['насеменил', 'щека', 'проверять'],
#  ['бля', 'шутка', 'муравей', 'скучать'],
#  ['пусть', 'твой', 'мамка', 'жопа', 'сперма', 'проверять'],
#  ['насру', 'съесть'],
#  ['охуительный', 'юмор', 'просто'],
#  [],
#  ['это', 'новый', 'ньюфаг', 'порваться', 'баттхерта', 'это', 'итт', 'тред'],
#  ['увидеть', 'баттхёрт', 'мальчик'],
#  ['бог', 'заебал', 'свой', 'таракан', 'мразь'],
#  ['мало', 'зайти', 'тхредты', 'посмотреть', 'ответить'],
#  ['таблетка'],
#  ['сказать', 'похуй', 'сказать', 'заебал', 'чмоха'],
#  ['никто', 'говорить', 'похуйнаоборот', 'сказать', 'мразь', 'бугуртишь'],
#  ['бамп'],
#  ['скучать'],
#  ['плохой',
#   'дегенерат',
#   'сралиным',
#   'додик',
#   'муравей',
#   'лопушок',
#   'тредшотами',
#   'боевой',
#   'картиночка'],
#  ['фокусник', 'ньюсача'],
#  ['сидеть', 'знаменитый'],
#  ['показывать', 'фокус', 'исчезновение'],
#  ['двачую', 'это', 'пидор'],
#  ['последний', 'время', 'заходить', 'тред', 'ради', 'муравей'],
#  ['знать', 'весь', 'двач', 'насиловать', 'жопа'],
#  ['думать', 'почему', 'говно', 'вываливаться', 'оно', 'оказаться'],
#  ['жение', 'простата', 'спасаться', 'простатит'],
#  ['пездный', 'сок', 'получать', 'хуй', 'приболеть'],
#  ['поспрашивать', 'знакомый'],
#  ['необязательно', 'ебаться', 'просто', 'втереть'],
#  ['сок', 'взять', 'знакомый', 'тян', 'самка', 'крайняк'],
#  ['ебанные', 'колхозник', 'нахуй', 'пездный', 'сок'],
#  ['правильно', 'это', 'называться', 'вагинальный', 'секрет'],
#  ['пользоваться', 'научиться', 'название', 'знать'],
#  ['хуец', 'казать'],
#  ['че', 'телепат', 'чтоли', 'хуй', 'чесать', 'двач'],
#  ['сок', 'делать'],
#  ['понадобиться', 'селёдочка', 'уксус', 'немного', 'соль'],
#  ['сок', 'блядь'],
#  ['кринжовые', 'клоун'],
#  ['пездный', 'сок'],
#  ['придумать'],
#  ['ох', 'мамкин', 'мамоновы'],
#  ['знать', 'нихуя', 'пизди', 'девственник', 'мамкин'],
#  ['прямо', 'стол', 'стоить', 'стакан', 'пездного', 'сок'],
#  ['жена', 'уехать', 'командировка', 'оставить', 'запас', 'втирание'],
#  ['клоун',
#   'хороший',
#   'кекал',
#   'посоветовать',
#   'действительно',
#   'полезный',
#   'опу'],
#  ['жена', 'оставить', 'ага'],
#  ['твой', 'рука', 'мочь', 'оставить'],
#  ['фантазёр', 'мамонов'],
#  ['пиздуй',
#   'урок',
#   'делать',
#   'чучело',
#   'мешать',
#   'учить',
#   'человек',
#   'ум',
#   'разум'],
#  ['эх', 'безотцовщина', 'небось'],
#  ['весь',
#   'нормальный',
#   'человек',
#   'батя',
#   'вещь',
#   'рассказывать',
#   'дарить',
#   'бутылочка',
#   'сбор',
#   'пездного',
#   'сок'],
#  ['это', 'визгливый', 'семенство'],
#  ['пидорашка', 'бимбо', 'унитаз', 'форсить', 'высралась'],
#  ['съеби', 'бутылка', 'клоун', 'говнофорсер'],
#  ['долбоеб', 'мозг', 'собрать', 'кекало', 'тупой'],
#  ['батя', 'подарить', 'корзинка', 'сбор', 'мозг'],
#  [],
#  ['попросить', 'ёлка', 'новый', 'год'],
#  ['душа', 'хуй', 'мыло', 'дрочить', 'ситуация'],
#  ['дрочить', 'мыломб'],
#  ['вообще',
#   'хуй',
#   'мыло',
#   'мыть',
#   'стрёмный',
#   'тема',
#   'купить',
#   'специальный',
#   'средство',
#   'интимный',
#   'гигиена',
#   'результат',
#   'сразу',
#   'заметить'],
#  ['дрочить', 'душа'],
#  ['следующий', 'день', 'душа', 'начать', 'зудеть'],
#  ['именно', 'кожа', 'ствол'],
#  ['зудеть', 'сильно'],
#  ['чесать', 'чесать', 'всё', 'никак', 'неначешишься'],
#  ['перестать', 'несколько', 'минута'],
#  ['грибок', 'купить', 'мазь', 'грибок'],
#  ['грибок', 'блядь'],
#  ['хуйце', 'грибок', 'бывать'],
#  ['онанировать'],
#  ['омегана', 'вроде', 'это', 'мочь', 'секрет'],
#  ['ровный', 'посонов', 'пездный', 'сок'],
#  ['шош', 'делать', 'аж', 'водка', 'морозилка', 'достать'],
#  ['оп', 'умереть'],
#  ['мимотян'],
#  ['ро', 'охуенна'],
#  ...]

# %%
cooccurence = Counter()

for doc in docs:
    for i in range(len(doc) - 1):
        cooccurence[(doc[i], doc[i + 1])] += 1

# %%
cooccurence.most_common(20)
# Out:
# [(('потому', 'что'), 164),
#  (('и', 'не'), 123),
#  (('а', 'не'), 102),
#  (('я', 'не'), 91),
#  (('у', 'меня'), 90),
#  (('это', 'не'), 76),
#  (('ты', 'не'), 73),
#  (('у', 'тебя'), 72),
#  (('что', 'то'), 64),
#  (('в', 'том'), 63),
#  (('он', 'не'), 59),
#  (('новый', 'год'), 59),
#  (('что', 'ты'), 56),
#  (('что', 'он'), 53),
#  (('а', 'если'), 52),
#  (('так', 'что'), 52),
#  (('если', 'ты'), 50),
#  (('то', 'что'), 49),
#  (('что', 'не'), 47),
#  (('не', 'в'), 45)]

# %%
N = sum(occurence.values())

N
# Out:
# 90315

# %%
pmi = Counter()
min_cooccur = 5

for pair in cooccurence:
    if cooccurence[pair] >= min_cooccur:
        pmi[pair] = np.log(cooccurence[pair] * N / occurence[pair[0]] / occurence[pair[1]])

# %%
pmi.most_common()
# Out:
# [(('проявление', 'гейства'), 9.801620926132557),
#  (('положения', 'расизма'), 9.801620926132557),
#  (('крайней', 'мере'), 9.801620926132557),
#  (('российской', 'федерации'), 9.801620926132557),
#  (('палю', 'годноту'), 9.801620926132557),
#  (('коллегами', 'пообщаться'), 9.801620926132557),
#  (('воняли', 'ссаками'), 9.801620926132557),
#  (('тестовое', 'задание'), 9.801620926132557),
#  (('оценивают', 'звездами'), 9.801620926132557),
#  (('пришедшим', 'сотрудникам'), 9.801620926132557),
#  (('полном', 'серьезе'), 9.801620926132557),
#  (('простейшими', 'базовыми'), 9.801620926132557),
#  (('базовыми', 'вещами'), 9.801620926132557),
#  (('вещами', 'справится'), 9.801620926132557),
#  (('социального', 'альфача'), 9.801620926132557),
#  (('омежкина', 'рожденного'), 9.801620926132557),
#  (('учёные', 'писатели'), 9.619299369338602),
#  (('писатели', 'инженеры'), 9.619299369338602),
#  (('целыми', 'днями'), 9.619299369338602),
#  (('языктатьяна', 'зигинова'), 9.619299369338602),
#  (('брачный', 'договор'), 9.619299369338602),
#  (('управляет', 'системами'), 9.619299369338602),
#  (('многомерные', 'функциональные'), 9.619299369338602),
#  (('митингах', 'селфпрезентации'), 9.619299369338602),
#  (('русскоговорящие', 'предпочитают'), 9.619299369338602),
#  (('коллаб', 'рефьюз'), 9.619299369338602),
#  (('алексея', 'нетесанова'), 9.619299369338602),
#  (('проверка', 'соцсетей'), 9.619299369338602),
#  (('особого', 'скила'), 9.619299369338602),
#  (('эстонская', 'фишка'), 9.619299369338602),
#  (('выполнят', 'трудовые'), 9.619299369338602),
#  (('исполнителен', 'сообразителен'), 9.619299369338602),
#  (('любое', 'проявление'), 9.465148689511345),
#  (('надписью', 'идиот'), 9.465148689511345),
#  (('немецкий', 'языктатьяна'), 9.465148689511345),
#  (('зал', 'персональной'), 9.465148689511345),
#  (('татьяна', 'зигиноваподключиться'), 9.465148689511345),
#  (('ретроспективы', 'проводить'), 9.465148689511345),
#  (('минимальный', 'набор'), 9.465148689511345),
#  (('вновь', 'пришедшим'), 9.465148689511345),
#  (('привести', 'чувака'), 9.465148689511345),
#  (('соответствовать', 'социальной'), 9.436977812544649),
#  (('социальной', 'адекватности'), 9.436977812544649),
#  (('ебашат', 'миллионы'), 9.331617296886822),
#  (('миллионы', 'транзакций'), 9.331617296886822),
#  (('функциональные', 'структуры'), 9.331617296886822),
#  (('митинг', 'коллаб'), 9.331617296886822),
#  (('ошибка', 'выжившего'), 9.331617296886822),
#  (('ебала', 'писание'), 9.331617296886822),
#  (('заказчиком', 'внутренним'), 9.331617296886822),
#  (('баклажан', 'уборщица'), 9.331617296886822),
#  (('конские', 'новогодние'), 9.331617296886822),
#  (('тащ', 'литинант'), 9.331617296886822),
#  (('глянь', 'патриот'), 9.28282713271739),
#  (('би', 'сексуал'), 9.213834261230438),
#  (('ниггерские', 'хуи'), 9.213834261230438),
#  (('разрабатывает', 'многомерные'), 9.213834261230438),
#  (('чек', 'трейни'), 9.213834261230438),
#  (('буквально', 'воняли'), 9.213834261230438),
#  (('коммерческой', 'конторе'), 9.213834261230438),
#  (('трудовые', 'обязанности'), 9.213834261230438),
#  (('бухалова', 'выставляет'), 9.213834261230438),
#  (('говяжьи', 'анусы'), 9.213834261230438),
#  (('изменила', 'парню'), 9.108473745572612),
#  (('чёрному', 'парню'), 9.108473745572612),
#  (('засольви', 'проблему'), 9.108473745572612),
#  (('джуна', 'особого'), 9.108473745572612),
#  (('небольшой', 'коммерческой'), 9.108473745572612),
#  (('отсеяла', 'скилловых'), 9.108473745572612),
#  (('заказать', 'услуги'), 9.04393522443504),
#  (('дороже', 'второго'), 9.031512704436484),
#  (('фирме', 'ущерб'), 9.031512704436484),
#  (('появятся', 'женщины'), 9.013163565768288),
#  (('женщины', 'учёные'), 9.013163565768288),
#  (('ебальником', 'светить'), 9.013163565768288),
#  (('чужом', 'коде'), 9.013163565768288),
#  (('хрюшу', 'уволил'), 9.013163565768288),
#  (('пользу', 'приносить'), 9.013163565768288),
#  (('вера', 'ивановна'), 9.013163565768288),
#  (('модель', 'кнопки'), 8.995145060265608),
#  (('тупых', 'пезд'), 8.926152188778657),
#  (('возьмет', 'социального'), 8.926152188778657),
#  (('студень', 'свёкла'), 8.926152188778657),
#  (('новогоднем', 'столе'), 8.926152188778657),
#  (('новым', 'годом'), 8.885330194258403),
#  (('конторе', 'сыну'), 8.877362024609226),
#  (('феминист', 'леволибералом'), 8.84610948110512),
#  (('организован', 'рабочий'), 8.84610948110512),
#  (('сисек', 'жены'), 8.830842008974333),
#  (('уметь', 'соответствовать'), 8.830842008974333),
#  (('слово', 'дороже'), 8.830842008974333),
#  (('личный', 'выбор'), 8.808369153122275),
#  (('спринт', 'чек'), 8.808369153122275),
#  (('активистом', 'мультикультуралист'), 8.7720015089514),
#  (('поддерживаю', 'феминизм'), 8.761849137487381),
#  (('спать', 'пойду'), 8.743830631984704),
#  (('ущерб', 'вполне'), 8.743830631984704),
#  (('некомпетентная', 'заигравшаяся'), 8.725481493316506),
#  (('конторами', 'редко'), 8.703008637464448),
#  (('обсуждая', 'пути'), 8.703008637464448),
#  (('задач', 'сухим'), 8.703008637464448),
#  (('план', 'горит'), 8.703008637464448),
#  (('доклады', 'круглые'), 8.694709834649753),
#  (('ума', 'составить'), 8.691958801277863),
#  (('круглые', 'столы'), 8.676691329147074),
#  (('рабочий', 'процесс'), 8.663787924311167),
#  (('абсолютна', 'равна'), 8.638470116326877),
#  (('ит', 'конторами'), 8.638470116326877),
#  (('тринадцатую', 'зарплату'), 8.638470116326877),
#  (('окружающую', 'среду'), 8.594795052824216),
#  (('мужики', 'глянь'), 8.589679952157445),
#  (('сыну', 'тети'), 8.589679952157445),
#  (('создадут', 'рабочее'), 8.589679952157445),
#  (('геи', 'бишки'), 8.577845494510441),
#  (('ебаный', 'нарисовался'), 8.577845494510441),
#  (('трейни', 'курс'), 8.577845494510441),
#  (('курс', 'засольви'), 8.577845494510441),
#  (('описанию', 'лид'), 8.577845494510441),
#  (('хватит', 'пиздеть'), 8.55842740865334),
#  (('являюсь', 'веганом'), 8.527655749986586),
#  (('равна', 'мужчине'), 8.520687080670493),
#  (('яд', 'никакого'), 8.520687080670493),
#  (('никакого', 'бога'), 8.520687080670493),
#  (('запланированную', 'конференцию'), 8.520687080670493),
#  (('дейли', 'митингах'), 8.520687080670493),
#  (('плохо', 'организован'), 8.520687080670493),
#  (('прикрепить', 'нормальное'), 8.520687080670493),
#  (('мультикультуралист', 'феминист'), 8.509637244483908),
#  (('новых', 'проектов'), 8.484319436499618),
#  (('редко', 'руководят'), 8.479865086150237),
#  (('тетя', 'срака'), 8.4741670650356),
#  (('зигинова', 'приглашает'), 8.466619859400218),
#  (('топовый', 'разработчик'), 8.466619859400218),
#  (('узнаваем', 'среди'), 8.466619859400218),
#  (('среди', 'коммюнити'), 8.466619859400216),
#  (('сформировавшиеся', 'взгляды'), 8.460062458854058),
#  (('джунами', 'менять'), 8.456148559532922),
#  (('люблю', 'любое'), 8.435529272330186),
#  (('принесет', 'фирме'), 8.425376900866167),
#  (('раньше', 'давили'), 8.423694814683184),
#  (('патриот', 'ебаный'), 8.395523937716487),
#  (('хорошее', 'требование'), 8.395523937716487),
#  (('этими', 'ебаными'), 8.395523937716487),
#  (('женщина', 'изменила'), 8.366536400843234),
#  (('тети', 'сраки'), 8.366536400843234),
#  (('профжаргон', 'наш'), 8.366536400843234),
#  (('сохранять', 'формальные'), 8.366536400843234),
#  (('командная', 'работа'), 8.366536400843234),
#  (('тёти', 'сраки'), 8.366536400843234),
#  (('открывает', 'профиль'), 8.366536400843234),
#  (('ебанное', 'которое'), 8.366536400843234),
#  (('ебанутые', 'садисты'), 8.366536400843234),
#  (('готов', 'бороться'), 8.361259343742391),
#  (('научный', 'атеист'), 8.341456716446212),
#  (('наука', 'помогает'), 8.338365523876538),
#  (('твоему', 'описанию'), 8.301997879705663),
#  (('холодец', 'свекла'), 8.301997879705663),
#  (('александр', 'павлович'), 8.275564622637509),
#  (('прошлом', 'году'), 8.275564622637509),
#  (('женщина', 'абсолютна'), 8.26117588518541),
#  (('первое', 'слово'), 8.259391763391907),
#  (('вебм', 'оценивает'), 8.239973677534806),
#  (('причинять', 'вред'), 8.233005008218711),
#  (('дейли', 'митинг'), 8.233005008218711),
#  (('россии', 'проходили'), 8.192183013698457),
#  (('нельзя', 'сохранять'), 8.192183013698457),
#  (('отношения', 'обсуждая'), 8.192183013698457),
#  (('сына', 'тёти'), 8.192183013698457),
#  (('изначально', 'отсеяла'), 8.192183013698457),
#  (('сраки', 'создадут'), 8.184214844049281),
#  (('предпочитают', 'говорить'), 8.152962300545175),
#  (('гитхабе', 'насколько'), 8.152962300545175),
#  (('девушка', 'встречающаяся'), 8.11522197256233),
#  (('сиськи', 'интересны'), 8.11522197256233),
#  (('остальные', 'буквально'), 8.11522197256233),
#  (('мои', 'сформировавшиеся'), 8.078854328391454),
#  (('брить', 'яйца'), 8.078854328391454),
#  (('формальные', 'привет'), 8.078854328391454),
#  (('посте', 'смотрел'), 8.057652120740851),
#  (('выбор', 'каждого'), 8.050683451424758),
#  (('писание', 'кода'), 8.043763008580184),
#  (('видно', 'листву'), 8.009861456904503),
#  (('сиськи', 'видит'), 8.009861456904503),
#  (('проблему', 'дейли'), 8.009861456904503),
#  (('менее', 'грамотное'), 8.009861456904503),
#  (('пойти', 'встретить'), 8.009861456904503),
#  (('ма', 'ам'), 8.009861456904503),
#  (('дай', 'бог'), 7.990058829608323),
#  (('принципе', 'уметь'), 7.9835441485871295),
#  (('умение', 'разбираться'), 7.9835441485871295),
#  (('сих', 'пор'), 7.9734938127336275),
#  (('будь', 'готов'), 7.955794235634227),
#  (('тема', 'зал'), 7.9453229357669315),
#  (('друг', 'другу'), 7.9453229357669315),
#  (('президент', 'молчал'), 7.9453229357669315),
#  (('хватает', 'ума'), 7.929818749230966),
#  (('делает', 'доклады'), 7.914551277100178),
#  (('машине', 'времени'), 7.914551277100178),
#  (('рабочее', 'место'), 7.914551277100178),
#  (('нормально', 'выполнят'), 7.914551277100178),
#  (('следующий', 'день'), 7.889612328752926),
#  (('хочет', 'котиков'), 7.884698313950497),
#  (('котиков', 'хочет'), 7.884698313950497),
#  (('пути', 'решения'), 7.8557107770772445),
#  (('решения', 'задач'), 7.8557107770772445),
#  (('программист', 'постоянно'), 7.8557107770772445),
#  (('жопах', 'молодых'), 7.8557107770772445),
#  (('молодых', 'пацанов'), 7.8557107770772445),
#  (('брить', 'пузо'), 7.850012755962607),
#  (('вред', 'животным'), 7.827539900110548),
#  (('веками', 'женщин'), 7.827539900110548),
#  (('женщин', 'угнетали'), 7.827539900110548),
#  (('должно', 'пытаться'), 7.827539900110548),
#  (('говнокодить', 'вместо'), 7.800140925922434),
#  (('вместо', 'омежкина'), 7.800140925922434),
#  (('русская', 'девушка'), 7.796768241443794),
#  (('нее', 'заказать'), 7.791172255939673),
#  (('й', 'скрипт'), 7.773472678840272),
#  (('членов', 'побывало'), 7.773472678840272),
#  (('вред', 'приносит'), 7.763001378972977),
#  (('давно', 'опровергла'), 7.76040059727292),
#  (('говорить', 'спринт'), 7.747497192437011),
#  (('самом', 'деле'), 7.7243556638753175),
#  (('проблемы', 'возникают'), 7.709756864454165),
#  (('гений', 'кода'), 7.676038228454867),
#  (('повидав', 'жизнь'), 7.67338922028329),
#  (('стоит', 'полагать'), 7.67338922028329),
#  (('инженеры', 'которых'), 7.649858722873096),
#  (('других', 'программистах'), 7.649858722873096),
#  (('довольно', 'урчишь'), 7.645218343316594),
#  (('выбирает', 'пизда'), 7.604396348796338),
#  (('отлично', 'умеет'), 7.604396348796338),
#  (('лгбт', 'активистом'), 7.5824174420775625),
#  (('проходили', 'лгбт'), 7.5824174420775625),
#  (('дед', 'мороз'), 7.5824174420775625),
#  (('составить', 'более'), 7.568028704625464),
#  (('оп', 'посте'), 7.53725704595871),
#  (('во', 'вторых'), 7.519238540456032),
#  (('сколько', 'сабскрайберов'), 7.519238540456032),
#  (('слишком', 'далеко'), 7.511108414372781),
#  (('сына', 'тети'), 7.499035833138512),
#  (('работать', 'исполнителен'), 7.499035833138512),
#  (('сычевальни', 'куда'), 7.499035833138512),
#  (('такую', 'хрюшу'), 7.487107262273238),
#  (('дохуя', 'ходит'), 7.486613313139955),
#  (('омежка', 'гений'), 7.4598151199852305),
#  (('батон', 'файлик'), 7.445130568302309),
#  (('хочу', 'причинять'), 7.440766925014536),
#  (('взгляды', 'ради'), 7.4384112113220775),
#  (('прямо', 'мгновенно'), 7.437000442219059),
#  (('наш', 'русский'), 7.4282667622503045),
#  (('ребенок', 'нахуя'), 7.422074792002384),
#  (('пизда', 'некомпетентная'), 7.403725653334187),
#  (('этой', 'хуйне'), 7.385707147831509),
#  (('кулич', 'кофта'), 7.385707147831509),
#  (('веганом', 'лгбт'), 7.381746746615412),
#  (('программиста', 'называется'), 7.379772412311694),
#  (('лгбт', 'парады'), 7.374778077299318),
#  (('нового', 'года'), 7.364504940180906),
#  (('формальные', 'отношения'), 7.344885153311254),
#  (('фоне', 'ковра'), 7.331103013796657),
#  (('приносит', 'вместо'), 7.330137296676698),
#  (('файл', 'ластик'), 7.289315302156442),
#  (('кажется', 'должно'), 7.267924112175125),
#  (('говно', 'ебанное'), 7.267924112175125),
#  (('довольно', 'неплохо'), 7.267924112175125),
#  (('человека', 'превыше'), 7.255305648215914),
#  (('ластик', 'бордюр'), 7.1979655235682145),
#  (('будут', 'здоровыми'), 7.1915511333905515),
#  (('код', 'доступа'), 7.148378961525343),
#  (('друг', 'друга'), 7.134392719550602),
#  (('свекла', 'кулич'), 7.113773432347867),
#  (('курс', 'дела'), 7.096240953586227),
#  (('свобода', 'человека'), 7.088251563552747),
#  (('тупая', 'пизда'), 7.057852642428268),
#  (('личное', 'дело'), 7.03261002524066),
#  (('персональной', 'конференции'), 7.029032203892776),
#  (('сможет', 'нормально'), 6.998260545226023),
#  (('должен', 'целыми'), 6.994630777175444),
#  (('команде', 'работать'), 6.988210209372522),
#  (('какого', 'хуя'), 6.98771033433087),
#  (('об', 'этом'), 6.980242039723344),
#  (('превыше', 'всего'), 6.968407582076342),
#  (('люди', 'занимаются'), 6.954924231739055),
#  (('файлик', 'ластик'), 6.95284306553523),
#  (('вряд', 'ли'), 6.922422468834518),
#  (('возьмёт', 'ни'), 6.922422468834518),
#  (('нахуя', 'мужу'), 6.911249168236393),
#  (('приглашает', 'вас'), 6.905384048783994),
#  (('том', 'числе'), 6.900199332049808),
#  (('ладно', 'первое'), 6.891446540940213),
#  (('батон', 'файл'), 6.890629881033657),
#  (('ее', 'собачье'), 6.889270261517617),
#  (('этой', 'хуйни'), 6.874881524065518),
#  (('конференции', 'татьяна'), 6.874881524065518),
#  (('права', 'женщин'), 6.8647291526015),
#  (('уравнять', 'тогда'), 6.857181946966117),
#  (('тогда', 'появятся'), 6.857181946966117),
#  (('тогда', 'шаболда'), 6.857181946966117),
#  (('системами', 'которые'), 6.8467106470988215),
#  (('которые', 'ебашат'), 6.8467106470988215),
#  (('которые', 'держит'), 6.8467106470988215),
#  (('таком', 'случае'), 6.840775911579007),
#  (('коврам', 'людей'), 6.836347860063275),
#  (('грамотное', 'резюме'), 6.836347860063275),
#  (('наука', 'давно'), 6.815938988432068),
#  (('неплохо', 'знаю'), 6.805888652578567),
#  (('которое', 'вред'), 6.797920482929389),
#  (('ни', 'разу'), 6.788891076209995),
#  (('бойфренда', 'себе'), 6.766667939425285),
#  (('себе', 'выбирает'), 6.766667939425285),
#  (('себе', 'финансовый'), 6.766667939425285),
#  (('заставляет', 'людей'), 6.762239887909553),
#  (('весь', 'двач'), 6.7570984884091345),
#  (('умные', 'люди'), 6.741350131440996),
#  (('говном', 'один'), 6.730781180091761),
#  (('речь', 'идет'), 6.728927611442439),
#  (('хочет', 'ковры'), 6.721547504144816),
#  (('собачье', 'блядь'), 6.719710956337514),
#  (('время', 'раскачаться'), 6.710578472774242),
#  (('нужно', 'уравнять'), 6.692559967271563),
#  (('людей', 'выбирать'), 6.654026303269321),
#  (('ебаными', 'резюме'), 6.654026303269321),
#  (('могу', 'понять'), 6.642070567349172),
#  (('листву', 'который'), 6.640374214100993),
#  (('битард', 'который'), 6.640374214100993),
#  (('альфача', 'который'), 6.640374214100993),
#  (('вы', 'няшки'), 6.623567095784612),
#  (('пол', 'года'), 6.615268292969917),
#  (('которых', 'раньше'), 6.608404848044935),
#  (('новый', 'год'), 6.596397190432684),
#  (('себя', 'наклейку'), 6.582745101264357),
#  (('чем', 'молитва'), 6.582745101264357),
#  (('тем', 'более'), 6.57355667520995),
#  (('этот', 'пост'), 6.562942473968177),
#  (('скорее', 'всего'), 6.562942473968177),
#  (('структуры', 'которые'), 6.559028574647041),
#  (('социоблядь', 'значит'), 6.5215454813923),
#  (('ему', 'кажется'), 6.5132190386157465),
#  (('ради', 'которых'), 6.510424439684731),
#  (('твоя', 'мать'), 6.503317967633035),
#  (('всю', 'жизнь'), 6.494734223941643),
#  (('опыта', 'работы'), 6.492538833378208),
#  (('эту', 'хуйню'), 6.471004978642491),
#  (('со', 'всеми'), 6.466174922033183),
#  (('такую', 'хуйню'), 6.4564061792213385),
#  (('помогает', 'больше'), 6.448850138375876),
#  (('идентификатор', 'конференции'), 6.441245538990657),
#  (('нахуя', 'брить'), 6.441245538990657),
#  (('быть', 'расистом'), 6.434325096146083),
#  (('лид', 'должен'), 6.423180531593019),
#  (('кстати', 'топовый'), 6.4124961257046715),
#  (('более', 'менее'), 6.400423544470402),
#  (('встретить', 'новый'), 6.400423544470402),
#  (('больше', 'членов'), 6.3947829171056005),
#  (('её', 'реакция'), 6.387178317720381),
#  (('каким', 'нибудь'), 6.383894242519192),
#  (('выпиздил', 'нахуй'), 6.380620917174222),
#  (('под', 'полтинник'), 6.374106236153029),
#  (('всегда', 'дают'), 6.3371358052344835),
#  (('спрашиваться', 'о'), 6.335885023332831),
#  (('о', 'человеке'), 6.335885023332831),
#  (('со', 'временем'), 6.306326221091287),
#  (('место', 'чисто'), 6.305113364666077),
#  (('считает', 'себя'), 6.295063028812576),
#  (('до', 'сих'), 6.287094859163399),
#  (('свадебные', 'фото'), 6.281160123643584),
#  (('фото', 'прикрепляет'), 6.281160123643584),
#  (('здоровым', 'можно'), 6.275260401516396),
#  (('их', 'оценивают'), 6.275260401516396),
#  (('через', 'минут'), 6.274191454327491),
#  (('веган', 'потому'), 6.257767244068879),
#  (('пофиг', 'чем'), 6.234438406996141),
#  (('оценивает', 'людей'), 6.2302120564929595),
#  (('вполне', 'себе'), 6.227671438692599),
#  (('со', 'мной'), 6.216714062401599),
#  (('даже', 'русскоговорящие'), 6.201572685725237),
#  (('при', 'этом'), 6.185312164853457),
#  (('сразу', 'видно'), 6.171581972041555),
#  (('ебли', 'потом'), 6.16053213585497),
#  (('взять', 'человека'), 6.126840396398123),
#  (('чемс', 'она'), 6.122791807872122),
#  (('кодить', 'она'), 6.122791807872122),
#  (('делать', 'сотрудник'), 6.112741472018621),
#  (('продолжают', 'до'), 6.104773302369445),
#  (('чел', 'выглядит'), 6.0994962452686),
#  (('свое', 'время'), 6.091539264368018),
#  (('со', 'стороны'), 6.083182669777077),
#  (('знаешь', 'всяких'), 6.078340045301289),
#  (('бога', 'нет'), 6.059200705090591),
#  (('конференции', 'код'), 6.024448864872943),
#  (('было', 'рас'), 6.0174312922142965),
#  (('знаю', 'плюсы'), 6.0174312922142965),
#  (('сам', 'би'), 6.011087818292121),
#  (('феминизм', 'потому'), 6.006452815787973),
#  (('до', 'ебли'), 5.999412786711618),
#  (('пытайся', 'меня'), 5.994217969834514),
#  (('берешь', 'их'), 5.987578329064616),
#  (('хоть', 'очко'), 5.983908600175653),
#  (('его', 'развивать'), 5.9773368350124185),
#  (('лет', 'назад'), 5.963929694123545),
#  (('будет', 'говнокодить'), 5.960020385000957),
#  (('ни', 'знакомых'), 5.941593215822792),
#  (('тех', 'кто'), 5.9370205992560185),
#  (('конференции', 'делает'), 5.930419915224666),
#  (('до', 'конца'), 5.919370079038082),
#  (('понимаю', 'зачем'), 5.913890613273456),
#  (('без', 'опыта'), 5.894701832622587),
#  (('люди', 'должны'), 5.889597920704412),
#  (('ожидает', 'от'), 5.889597920704412),
#  (('должна', 'быть'), 5.874709308210661),
#  (('даже', 'говном'), 5.865100449104024),
#  (('ебет', 'ее'), 5.847816386689456),
#  (('должно', 'быть'), 5.846538431243965),
#  (('пишет', 'один'), 5.843477985090859),
#  (('уволил', 'бы'), 5.831329012580436),
#  (('бы', 'выпиздил'), 5.831329012580436),
#  (('бы', 'вылезти'), 5.831329012580436),
#  (('ни', 'друзей'), 5.823810180166408),
#  (('друзей', 'ни'), 5.823810180166408),
#  (('перемешаться', 'чтобы'), 5.8126368795682835),
#  (('рожденного', 'чтобы'), 5.8126368795682835),
#  (('чтобы', 'кодить'), 5.8126368795682835),
#  (('до', 'нового'), 5.801587043381698),
#  (('ведь', 'действительно'), 5.7993916528182625),
#  (('нормальное', 'фото'), 5.78868363854579),
#  (('отличии', 'от'), 5.784237405046585),
#  (('насрать', 'хоть'), 5.747519822111422),
#  (('мороз', 'говно'), 5.741867808680076),
#  (('вас', 'плохо'), 5.7356758384321544),
#  (('всего', 'лишь'), 5.715644613580974),
#  (('всё', 'равно'), 5.713778941398024),
#  (('мешает', 'тебе'), 5.7028417668425915),
#  (('хуй', 'знает'), 5.6948538439119),
#  (('каждый', 'день'), 5.692387751416706),
#  (('конференции', 'конференции'), 5.691528006942318),
#  (('блядь', 'шебм'), 5.690091539156356),
#  (('почему', 'вам'), 5.687473736614277),
#  (('вы', 'двачер'), 5.668055650757176),
#  (('кавказцем', 'или'), 5.652157064689377),
#  (('или', 'афроамериканцем'), 5.652157064689377),
#  (('приложуха', 'для'), 5.652157064689377),
#  (('пообщаться', 'или'), 5.652157064689377),
#  (('понятный', 'для'), 5.652157064689377),
#  (('внутренним', 'или'), 5.652157064689377),
#  (('или', 'сторонним'), 5.652157064689377),
#  (('или', 'выпездываться'), 5.652157064689377),
#  (('её', 'профиль'), 5.6452409729910045),
#  (('людей', 'жениться'), 5.642425391590841),
#  (('к', 'сожалению'), 5.630315322774329),
#  (('екатеринбургподключиться', 'к'), 5.630315322774329),
#  (('зигиноваподключиться', 'к'), 5.630315322774329),
#  (('к', 'машине'), 5.630315322774329),
#  (('ко', 'мне'), 5.620264986920827),
#  (('будешь', 'работать'), 5.611966184106132),
#  (('больше', 'социоблядь'), 5.597591876772576),
#  (('мужу', 'фото'), 5.58801294308364),
#  (('держит', 'только'), 5.576248101504053),
#  (('только', 'горшки'), 5.576248101504053),
#  (('хоть', 'немного'), 5.550272615100792),
#  (('который', 'сиськи'), 5.541761925432883),
#  (('для', 'управления'), 5.5186256720648545),
#  (('какой', 'нибудь'), 5.517727897827605),
#  (('хоть', 'фотки'), 5.513904970929917),
#  (('подключиться', 'к'), 5.512532287117945),
#  (('для', 'жен'), 5.498006384862119),
#  (('мгновенно', 'бы'), 5.494856775959223),
#  (('фото', 'сисек'), 5.492702763279314),
#  (('дают', 'время'), 5.486803041152126),
#  (('вместо', 'того'), 5.485133312929831),
#  (('состоял', 'из'), 5.470887585846227),
#  (('козявки', 'из'), 5.470887585846227),
#  (('из', 'носа'), 5.470887585846227),
#  (('вылезти', 'из'), 5.470887585846227),
#  (('из', 'сычевальни'), 5.470887585846227),
#  (('эта', 'пизда'), 5.464330185300067),
#  (('к', 'тому'), 5.463261238111162),
#  (('главное', 'чтобы'), 5.4379434301268725),
#  (('тому', 'же'), 5.426893593940288),
#  (('который', 'дохуя'), 5.4239788897765),
#  (('эти', 'вещи'), 5.419594291458676),
#  (('когда', 'работал'), 5.416266501366001),
#  (('он', 'узнаваем'), 5.404705678964925),
#  (('он', 'наговорил'), 5.404705678964925),
#  (('всем', 'похуй'), 5.399791664162496),
#  (('днями', 'только'), 5.393926544710098),
#  (('от', 'джуна'), 5.378772296938421),
#  (('все', 'положения'), 5.377972616767856),
#  (('все', 'перемешаться'), 5.377972616767856),
#  (('других', 'людей'), 5.377732837363759),
#  (('меня', 'учить'), 5.375178761428291),
#  (('эта', 'хуйня'), 5.369020005495742),
#  (('нужно', 'знать'), 5.357558900539223),
#  (('она', 'принесет'), 5.334334447507852),
#  (('люди', 'давно'), 5.324284111654351),
#  (('меньше', 'чем'), 5.283462117134096),
#  (('нахуй', 'никому'), 5.282008628506113),
#  (('горшки', 'за'), 5.2798323490835175),
#  (('приносить', 'за'), 5.2798323490835175),
#  (('за', 'окном'), 5.2798323490835175),
#  (('чувака', 'за'), 5.2798323490835175),
#  (('она', 'возьмет'), 5.247323070518223),
#  (('или', 'разрабатывает'), 5.246691956581213),
#  (('один', 'вопрос'), 5.242704124661928),
#  (('женщин', 'нужно'), 5.237272734664721),
#  (('же', 'хочется'), 5.237272734664721),
#  (('идет', 'о'), 5.237272734664721),
#  (('вчера', 'так'), 5.231042184914085),
#  (('все', 'небинарные'), 5.223821936940598),
#  (('по', 'сравнению'), 5.220743432713511),
#  (('по', 'крайней'), 5.220743432713511),
#  (('по', 'сути'), 5.220743432713511),
#  (('по', 'поводу'), 5.220743432713511),
#  (('по', 'моему'), 5.220743432713511),
#  (('по', 'факту'), 5.220743432713511),
#  (('по', 'ковру'), 5.220743432713511),
#  (('по', 'кадрам'), 5.220743432713511),
#  (('по', 'подбору'), 5.220743432713511),
#  (('по', 'плечу'), 5.220743432713511),
#  (('пасху', 'они'), 5.216653447461986),
#  (('она', 'абсолютно'), 5.206501075997967),
#  (('она', 'изначально'), 5.206501075997967),
#  (('его', 'команды'), 5.204146946778937),
#  (('других', 'код'), 5.178938315059835),
#  (('интересны', 'только'), 5.170782993395888),
#  (('за', 'ручку'), 5.146300956458995),
#  (('значит', 'лучше'), 5.13525112027241),
#  (('могут', 'быть'), 5.122138707179914),
#  (('во', 'время'), 5.121343267657661),
#  (('про', 'формальные'), 5.114870753152043),
#  (('очень', 'много'), 5.112569256163764),
#  (('чисто', 'под'), 5.101140560340141),
#  (('каждый', 'год'), 5.091108406470113),
#  (('по', 'нему'), 5.087212040088988),
#  (('о', 'работе'), 5.083122054837463),
#  (('чего', 'стоит'), 5.083122054837463),
#  (('за', 'щеку'), 5.079161653621366),
#  (('прямо', 'сейчас'), 5.078845498070202),
#  (('нормальные', 'фото'), 5.077187319317648),
#  (('видит', 'только'), 5.065422477738062),
#  (('возникают', 'из'), 5.065422477738062),
#  (('тот', 'который'), 5.053409157518951),
#  (('пишется', 'для'), 5.046021261119062),
#  (('опровергла', 'все'), 5.041500380146643),
#  (('все', 'сайты'), 5.041500380146643),
#  (('пусть', 'хоть'), 5.028397155148216),
#  (('чтобы', 'пользу'), 5.024179519204013),
#  (('о', 'таком'), 5.023698634366662),
#  (('должен', 'делать'), 4.992150276631736),
#  (('за', 'ебала'), 4.992150276631736),
#  (('бы', 'рабочее'), 4.984031152193232),
#  (('по', 'твоему'), 4.979581375896623),
#  (('все', 'остальное'), 4.972507508659692),
#  (('все', 'черное'), 4.972507508659692),
#  (('у', 'сомелье'), 4.971708467466559),
#  (('парню', 'или'), 4.959009884129432),
#  (('или', 'мужу'), 4.959009884129432),
#  (('хотя', 'бы'), 4.955860275226536),
#  (('за', 'бред'), 4.943360112462305),
#  (('услуги', 'по'), 4.93306136026173),
#  (('те', 'кто'), 4.912174460827519),
#  (('иди', 'нахуй'), 4.9047143973646445),
#  (('занимаются', 'у'), 4.897600495312838),
#  (('от', 'которого'), 4.859978503523253),
#  (('если', 'программист'), 4.842138585394922),
#  (('чем', 'люди'), 4.839775796205734),
#  (('раз', 'жениться'), 4.83877629587265),
#  (('как', 'таковых'), 4.837378671606013),
#  (('выглядят', 'как'), 4.837378671606013),
#  (('о', 'том'), 4.820757790369972),
#  (('ковры', 'его'), 4.814186025206737),
#  (('за', 'джунами'), 4.809828719837782),
#  (('каждый', 'раз'), 4.7982849345179135),
#  (('нужен', 'какой'), 4.792319855049438),
#  (('мне', 'насрать'), 4.7777404052862815),
#  (('уже', 'насрать'), 4.765317885287724),
#  (('должен', 'быть'), 4.765167949010361),
#  (('к', 'чему'), 4.754846585420428),
#  (('больше', 'чем'), 4.752070215786628),
#  (('минуту', 'или'), 4.735866332815222),
#  (('речь', 'про'), 4.730024932246614),
#  (('однако', 'он'), 4.71155849840498),
#  (('все', 'равно'), 4.7114936832900725),
#  (('сторонним', 'то'), 4.707870725325795),
#  (('как', 'правило'), 4.70384727898149),
#  (('за', 'собой'), 4.692045684181398),
#  (('потом', 'опять'), 4.6903562907543765),
#  (('щас', 'бы'), 4.686196708277433),
#  (('цеху', 'у'), 4.6840263950147785),
#  (('кто', 'нибудь'), 4.680800410376793),
#  (('у', 'нас'), 4.678360657479101),
#  (('тян', 'которая'), 4.6681782027747545),
#  (('для', 'других'), 4.663545671235596),
#  (('как', 'бомж'), 4.655057114812058),
#  (('вопросы', 'о'), 4.644209012661759),
#  (('почти', 'нет'), 4.637815024159431),
#  (('совета', 'у'), 4.635236230845346),
#  (('раз', 'уж'), 4.626601775929014),
#  (('сраки', 'из'), 4.623589725459023),
#  (('со', 'своей'), 4.601578128852862),
#  (('фото', 'должно'), 4.5947611700733555),
#  (('у', 'неё'), 4.566243359358395),
#  (('котом', 'у'), 4.566243359358395),
#  (('её', 'дело'), 4.562629025669335),
#  (('того', 'чтобы'), 4.553681940824994),
#  (('привет', 'как'), 4.549696599154231),
#  (('это', 'зайки'), 4.5296475349241225),
#  (('это', 'наклеить'), 4.5296475349241225),
#  (('афроамериканцем', 'это'), 4.5296475349241225),
#  (('это', 'яд'), 4.5296475349241225),
#  (('разработчик', 'это'), 4.5296475349241225),
#  (('соцсетей', 'это'), 4.5296475349241225),
#  (('человека', 'который'), 4.525841352609887),
#  (('да', 'ладно'), 4.521340247070672),
#  (('рас', 'как'), 4.518924940487477),
#  (('каждый', 'может'), 4.511083746903483),
#  (('к', 'конференции'), 4.506385226121929),
#  (('может', 'быть'), 4.48841494709077),
#  (('он', 'сможет'), 4.48841494709077),
#  (('захочет', 'если'), 4.48546364145619),
#  (('по', 'этому'), 4.466971630337131),
#  (('я', 'веган'), 4.461887455867804),
#  (('лучше', 'чем'), 4.458851797013687),
#  (('по', 'пути'), 4.458603380666614),
#  (('насколько', 'он'), 4.449194233937489),
#  (('хотел', 'бы'), 4.445034651460545),
#  (('чтобы', 'больше'), 4.433947117833612),
#  (('кандидатов', 'по'), 4.432286072349241),
#  (('ты', 'несешь'), 4.429820782824717),
#  (('можно', 'найти'), 4.429433711018065),
#  (('будет', 'месяц'), 4.419575344053809),
#  (('хочу', 'чтобы'), 4.407294323477698),
#  (('наклейку', 'с'), 4.404363611729617),
#  (('с', 'надписью'), 4.404363611729617),
#  (('встречающаяся', 'с'), 4.404363611729617),
#  (('с', 'кавказцем'), 4.404363611729617),
#  (('с', 'пастой'), 4.404363611729617),
#  (('с', 'борды'), 4.404363611729617),
#  (('с', 'экрана'), 4.404363611729617),
#  (('сравнению', 'с'), 4.404363611729617),
#  (('с', 'детьми'), 4.404363611729617),
#  (('с', 'мамкой'), 4.404363611729617),
#  (('с', 'челочкой'), 4.404363611729617),
#  (('с', 'коллегами'), 4.404363611729617),
#  (('шаболда', 'с'), 4.404363611729617),
#  (('с', 'ковром'), 4.404363611729617),
#  (('с', 'шариком'), 4.404363611729617),
#  (('ладить', 'с'), 4.404363611729617),
#  (('с', 'коллективом'), 4.404363611729617),
#  (('с', 'бабкой'), 4.404363611729617),
#  (('с', 'заказчиком'), 4.404363611729617),
#  (('выпездываться', 'с'), 4.404363611729617),
#  (('с', 'простейшими'), 4.404363611729617),
#  (('коме', 'с'), 4.404363611729617),
#  (('с', 'бухалова'), 4.404363611729617),
#  (('цитатки', 'с'), 4.404363611729617),
#  (('с', 'семьей'), 4.404363611729617),
#  (('с', 'наступающим'), 4.404363611729617),
#  (('с', 'плюсами'), 4.404363611729617),
#  (('после', 'этого'), 4.392478004495636),
#  (('блядь', 'дело'), 4.384336040520478),
#  (('все', 'таки'), 4.379443786656729),
#  (('небинарные', 'это'), 4.3754968550968645),
#  (('расистом', 'это'), 4.3754968550968645),
#  (('вот', 'прямо'), 4.372275297178117),
#  (('ты', 'берешь'), 4.365282261687146),
#  (('тупой', 'чтобы'), 4.357349646961441),
#  (('я', 'либерал'), 4.354256791675438),
#  (('место', 'для'), 4.352874080559117),
#  (('блядь', 'пиздец'), 4.3481329918565175),
#  (('адекватности', 'это'), 4.3473259781301685),
#  (('за', 'неделю'), 4.3353707402426656),
#  (('с', 'помощью'), 4.3302556395758955),
#  (('как', 'минимум'), 4.326553047840021),
#  (('из', 'дс'), 4.318208075907841),
#  (('бред', 'ты'), 4.316492097517714),
#  (('бы', 'такую'), 4.305272709085386),
#  (('с', 'ними'), 4.304280153172635),
#  (('у', 'мастеров'), 4.278561286906614),
#  (('у', 'парня'), 4.278561286906614),
#  (('я', 'учусь'), 4.276965117373792),
#  (('может', 'делать'), 4.272191838621135),
#  (('бы', 'хотел'), 4.262713094666591),
#  (('ты', 'идёшь'), 4.2474992260307625),
#  (('из', 'дома'), 4.247112154224111),
#  (('думают', 'что'), 4.24711215422411),
#  (('полагать', 'что'), 4.24711215422411),
#  (('должны', 'все'), 4.238538333579491),
#  (('для', 'сына'), 4.225040709049232),
#  (('с', 'большим'), 4.222042054935662),
#  (('созвоне', 'с'), 4.222042054935662),
#  (('с', 'котом'), 4.222042054935662),
#  (('лгбт', 'потому'), 4.220885316807839),
#  (('но', 'зато'), 4.219199308480624),
#  (('с', 'этими'), 4.21020759728866),
#  (('у', 'меня'), 4.208827948891939),
#  (('потому', 'что'), 4.193686987550531),
#  (('религия', 'это'), 4.19317529830291),
#  (('о', 'других'), 4.184122820073369),
#  (('за', 'минуту'), 4.1812200604154075),
#  (('с', 'новым'), 4.1812200604154075),
#  (('он', 'сегодня'), 4.180930247342809),
#  (('у', 'него'), 4.173200771248788),
#  (('что', 'заставляет'), 4.173004182070389),
#  (('брат', 'ты'), 4.160487849041133),
#  (('какое', 'же'), 4.158863153314131),
#  (('из', 'этих'), 4.149131745863907),
#  (('у', 'нее'), 4.124410607079356),
#  (('это', 'личный'), 4.124182426815959),
#  (('это', 'прекрасно'), 4.124182426815959),
#  (('мастеров', 'с'), 4.116681539277836),
#  (('с', 'местной'), 4.116681539277836),
#  (('я', 'являюсь'), 4.109911032710626),
#  (('что', 'спросишь'), 4.092961474396852),
#  (('двачер', 'то'), 4.088831516919572),
#  (('брать', 'или'), 4.0835411467755325),
#  (('дело', 'когда'), 4.082340125763427),
#  (('выглядит', 'как'), 4.079692969908496),
#  (('кода', 'для'), 4.076620703930958),
#  (('люди', 'которые'), 4.074121924859041),
#  (('верю', 'что'), 4.064790597430156),
#  (('резюме', 'без'), 4.063759137823494),
#  (('какое', 'то'), 4.061243560400743),
#  (('контора', 'это'), 4.059643905678387),
#  (('только', 'социоблядь'), 4.050191798009004),
#  (('нас', 'было'), 4.050107048655167),
#  (('ты', 'живёшь'), 4.046828530568612),
#  (('уже', 'давно'), 4.030927746193729),
#  (('очевидно', 'же'), 4.025331760689609),
#  (('разве', 'что'), 4.023968602909901),
#  (('у', 'них'), 4.023669037277824),
#  (('с', 'тобой'), 4.021371359473512),
#  (('какую', 'то'), 4.01472354476585),
#  (('под', 'новый'), 4.002528271672031),
#  (('спасибо', 'за'), 3.998898503621453),
#  (('общаться', 'с'), 3.998898503621453),
#  (('с', 'удава'), 3.998898503621453),
#  (('какая', 'то'), 3.996374406097653),
#  (('о', 'чем'), 3.9924779358185303),
#  (('я', 'поддерживаю'), 3.989283044922011),
#  (('считают', 'что'), 3.95943008177233),
#  (('с', 'друзьями'), 3.95237848798656),
#  (('под', 'него'), 3.9379897505344603),
#  (('считаю', 'что'), 3.9286584231055763),
#  (('если', 'женщина'), 3.925847853520767),
#  (('вузе', 'на'), 3.9238851443529184),
#  (('на', 'окружающую'), 3.9238851443529184),
#  (('на', 'веганстве'), 3.9238851443529184),
#  (('наклеить', 'на'), 3.9238851443529184),
#  (('на', 'основе'), 3.9238851443529184),
#  (('на', 'колени'), 3.9238851443529184),
#  (('на', 'производстве'), 3.9238851443529184),
#  (('на', 'рынке'), 3.9238851443529184),
#  (('на', 'запланированную'), 3.9238851443529184),
#  (('на', 'втором'), 3.9238851443529184),
#  (('на', 'даче'), 3.9238851443529184),
#  (('похоже', 'на'), 3.9238851443529184),
#  (('ковёр', 'на'), 3.9238851443529184),
#  (('на', 'фотке'), 3.9238851443529184),
#  (('звездами', 'на'), 3.9238851443529184),
#  (('на', 'западе'), 3.9238851443529184),
#  (('наговорил', 'на'), 3.9238851443529184),
#  (('на', 'стройке'), 3.9238851443529184),
#  (('на', 'полном'), 3.9238851443529184),
#  (('на', 'картинке'), 3.9238851443529184),
#  (('на', 'собеседование'), 3.9238851443529184),
#  (('на', 'практике'), 3.9238851443529184),
#  (('на', 'документы'), 3.9238851443529184),
#  (('на', 'нём'), 3.9238851443529184),
#  (('на', 'броне'), 3.9238851443529184),
#  (('на', 'кухне'), 3.9238851443529184),
#  (('на', 'зону'), 3.9238851443529184),
#  (('у', 'вас'), 3.9094638229693244),
#  (('дело', 'вообще'), 3.9051999277114695),
#  (('для', 'этого'), 3.9004029300750216),
#  (('кому', 'то'), 3.8969405091094664),
#  (('к', 'нам'), 3.895714267386222),
#  (('с', 'первого'), 3.8935379879636267),
#  (('как', 'называется'), 3.881867226578576),
#  (('на', 'фоне'), 3.86672673051297),
#  (('с', 'ним'), 3.8653671109969303),
#  (('у', 'кого'), 3.852476891595714),
#  (('до', 'чего'), 3.8509783735448306),
#  (('я', 'готов'), 3.8482044466621055),
#  (('на', 'питоне'), 3.843842436679382),
#  (('что', 'фрики'), 3.841647046115946),
#  (('на', 'сгуху'), 3.8368737673632887),
#  (('мужу', 'это'), 3.8365003543641776),
#  (('хоть', 'раз'), 3.8244243508222806),
#  (('плевать', 'на'), 3.818524628695092),
#  (('на', 'русском'), 3.818524628695092),
#  (('один', 'раз'), 3.809156878691492),
#  (('у', 'каждого'), 3.8085576576608786),
#  (('я', 'считаю'), 3.8069614881280565),
#  (('от', 'того'), 3.7977338590260183),
#  (('если', 'омежка'), 3.7923164608962447),
#  (('то', 'пойти'), 3.79157999345164),
#  (('нажимаете', 'на'), 3.790353751728396),
#  (('которые', 'можно'), 3.790353751728396),
#  (('по', 'работе'), 3.785658907424188),
#  (('можно', 'быть'), 3.783433308883822),
#  (('мне', 'похуй'), 3.7819855020578794),
#  (('на', 'дваче'), 3.780784300712245),
#  (('про', 'него'), 3.7773665562015846),
#  (('сказали', 'что'), 3.777108524978375),
#  (('напишите', 'что'), 3.777108524978375),
#  (('с', 'людьми'), 3.7757549523072433),
#  (('на', 'следующий'), 3.7697344645256603),
#  (('смотрят', 'на'), 3.7697344645256603),
#  (('на', 'собесе'), 3.7697344645256603),
#  (('с', 'ней'), 3.7683748450096206),
#  (('рядом', 'с'), 3.7625097255572224),
#  (('знал', 'что'), 3.76160433844241),
#  (('такая', 'же'), 3.755668193740506),
#  (('которым', 'я'), 3.7481209881051227),
#  (('зачем', 'они'), 3.7448369129039327),
#  (('для', 'того'), 3.742614559804939),
#  (('на', 'созвоне'), 3.741563587558964),
#  (('звать', 'на'), 3.741563587558964),
#  (('за', 'месяц'), 3.739387308136368),
#  (('на', 'самом'), 3.7190907317069053),
#  (('на', 'бутылку'), 3.716245779574674),
#  (('общение', 'с'), 3.711216431169672),
#  (('с', 'такими'), 3.711216431169672),
#  (('за', 'минут'), 3.711216431169672),
#  (('парня', 'с'), 3.711216431169672),
#  (('говорю', 'что'), 3.7081156534914235),
#  (('от', 'него'), 3.7047958633667495),
#  (('все', 'эти'), 3.703996183196185),
#  (('от', 'этого'), 3.70252571483221),
#  (('там', 'нужен'), 3.6999575867264998),
#  (('какие', 'фото'), 3.6944707795456417),
#  (('для', 'работы'), 3.6780760386673674),
#  (('на', 'собес'), 3.6725707160720122),
#  (('на', 'улице'), 3.6615208798854275),
#  (('у', 'тебя'), 3.6536632068807755),
#  (('если', 'оно'), 3.652554518521086),
#  (('резюме', 'фото'), 3.6523592941955147),
#  (('какого', 'то'), 3.6518180510764813),
#  (('до', 'этого'), 3.6480375295481404),
#  (('день', 'по'), 3.6452070719550917),
#  (('ты', 'будешь'), 3.641363422460447),
#  (('на', 'цеху'), 3.6362030719011376),
#  (('реакция', 'на'), 3.6362030719011376),
#  (('на', 'новогоднем'), 3.6362030719011376),
#  (('не', 'верю'), 3.6336852359087963),
#  (('не', 'нравятся'), 3.6336852359087963),
#  (('не', 'разбираюсь'), 3.6336852359087963),
#  (('не', 'побывав'), 3.6336852359087963),
#  (('не', 'вольется'), 3.6336852359087963),
#  (('не', 'пытайся'), 3.6336852359087963),
#  (('не', 'выглядят'), 3.6336852359087963),
#  (('не', 'использует'), 3.6336852359087963),
#  (('не', 'ожидает'), 3.6336852359087963),
#  (('сотрудникам', 'не'), 3.6336852359087963),
#  (('не', 'завезли'), 3.6336852359087963),
#  (('не', 'возьмёт'), 3.6336852359087963),
#  (('не', 'запомним'), 3.6336852359087963),
#  (('не', 'поладил'), 3.6336852359087963),
#  (('справится', 'не'), 3.6336852359087963),
#  (('не', 'бойфренда'), 3.6336852359087963),
#  (('не', 'спрашиваю'), 3.6336852359087963),
#  (('как', 'показывает'), 3.6334058672800764),
#  (('с', 'вебм'), 3.6311737234961354),
#  (('русский', 'у'), 3.6279737207654645),
#  (('у', 'ковра'), 3.6279737207654645),
#  (('к', 'себе'), 3.6249817532482145),
#  (('в', 'вузе'), 3.6236768120819574),
#  (('в', 'отличии'), 3.6236768120819574),
#  (('в', 'течение'), 3.6236768120819574),
#  (('в', 'рашке'), 3.6236768120819574),
#  (('в', 'общем'), 3.6236768120819574),
#  (('в', 'штатах'), 3.6236768120819574),
#  (('в', 'целом'), 3.6236768120819574),
#  (('в', 'конце'), 3.6236768120819574),
#  (('в', 'паспорте'), 3.6236768120819574),
#  (('в', 'принципе'), 3.6236768120819574),
#  (('в', 'школе'), 3.6236768120819574),
#  (('в', 'зеркале'), 3.6236768120819574),
#  (('в', 'порно'), 3.6236768120819574),
#  (('в', 'папке'), 3.6236768120819574),
#  (('в', 'обще'), 3.6236768120819574),
#  (('в', 'людях'), 3.6236768120819574),
#  (('транзакций', 'в'), 3.6236768120819574),
#  (('побывав', 'в'), 3.6236768120819574),
#  (('вольется', 'в'), 3.6236768120819574),
#  (('в', 'основном'), 3.6236768120819574),
#  (('в', 'антикафе'), 3.6236768120819574),
#  (('в', 'фирму'), 3.6236768120819574),
#  (('в', 'коллективе'), 3.6236768120819574),
#  (('в', 'офисе'), 3.6236768120819574),
#  (('в', 'решении'), 3.6236768120819574),
#  (('в', 'чемс'), 3.6236768120819574),
#  (('в', 'ротеш'), 3.6236768120819574),
#  (('в', 'чужом'), 3.6236768120819574),
#  (('в', 'фейсбуках'), 3.6236768120819574),
#  (('в', 'костюме'), 3.6236768120819574),
#  (('в', 'пейсбуке'), 3.6236768120819574),
#  (('в', 'коме'), 3.6236768120819574),
#  (('в', 'тиндере'), 3.6236768120819574),
#  (('в', 'команде'), 3.6236768120819574),
#  (('в', 'нужном'), 3.6236768120819574),
#  (('въезжаешь', 'в'), 3.6236768120819574),
#  (('в', 'прошлом'), 3.6236768120819574),
#  (('вернуться', 'в'), 3.6236768120819574),
#  (('в', 'интернете'), 3.6236768120819574),
#  (('в', 'вебе'), 3.6236768120819574),
#  (('в', 'реанимацию'), 3.6236768120819574),
#  (('побывало', 'в'), 3.6236768120819574),
#  (('в', 'жопах'), 3.6236768120819574),
#  (('в', 'крысу'), 3.6236768120819574),
#  (('в', 'реанимации'), 3.6236768120819574),
#  (('с', 'утра'), 3.615906251365347),
#  (('один', 'из'), 3.6119888137805427),
#  (('можно', 'было'), 3.5979818590809396),
#  (('про', 'них'), 3.59504499940763),
#  (('а', 'затем'), 3.5790446580611888),
#  (('не', 'пускает'), 3.5730606140923618),
#  (('на', 'гитхабе'), 3.5672102004141863),
#  (('в', 'итоге'), 3.5665183982420086),
#  (('ну', 'чего'), 3.5570657513424138),
#  (('что', 'захочет'), 3.5539649736641654),
#  (('я', 'научный'), 3.5539649736641654),
#  (('не', 'вредит'), 3.55364252823526),
#  (('в', 'курсе'), 3.5495688399282352),
#  (('в', 'спальне'), 3.5436341044084205),
#  (('всё', 'время'), 3.525604199581722),
#  (('на', 'форч'), 3.518420036244754),
#  (('производстве', 'на'), 3.518420036244754),
#  (('в', 'состоянии'), 3.518316296424131),
#  (('пасха', 'это'), 3.518046623245643),
#  (('конечно', 'же'), 3.5145061369236177),
#  (('без', 'фото'), 3.5085714014038034),
#  (('нужно', 'быть'), 3.507585694079044),
#  (('какие', 'то'), 3.507475742347743),
#  (('в', 'совке'), 3.505893776425574),
#  (('если', 'человек'), 3.5046343884444635),
#  (('до', 'того'), 3.5020836169250606),
#  (('я', 'думал'), 3.4968065598242166),
#  (('я', 'работаю'), 3.4968065598242166),
#  (('на', 'плюсах'), 3.4931022282604642),
#  (('вот', 'этот'), 3.490249159278058),
#  (('такой', 'же'), 3.4898135243332464),
#  (('деле', 'он'), 3.4877830667828644),
#  (('нам', 'по'), 3.4861423773254043),
#  (('каких', 'то'), 3.4840952937036795),
#  (('мне', 'лет'), 3.482652812386123),
#  (('леволибералом', 'и'), 3.479774077040767),
#  (('бишки', 'и'), 3.479774077040767),
#  (('и', 'счастливыми'), 3.479774077040767),
#  (('и', 'прочее'), 3.479774077040767),
#  (('и', 'тд'), 3.479774077040767),
#  (('и', 'прочие'), 3.479774077040767),
#  (('селфпрезентации', 'и'), 3.479774077040767),
#  (('и', 'ретроспективы'), 3.479774077040767),
#  (('и', 'спрашиваться'), 3.479774077040767),
#  (('ссаками', 'и'), 3.479774077040767),
#  (('сухим', 'и'), 3.479774077040767),
#  (('и', 'профессиональным'), 3.479774077040767),
#  (('раскачаться', 'и'), 3.479774077040767),
#  (('и', 'понятным'), 3.479774077040767),
#  (('фейсбуках', 'и'), 3.479774077040767),
#  (('и', 'коврам'), 3.479774077040767),
#  (('и', 'прикрепить'), 3.479774077040767),
#  (('выставляет', 'и'), 3.479774077040767),
#  (('и', 'цитатки'), 3.479774077040767),
#  (('сообразителен', 'и'), 3.479774077040767),
#  (('и', 'профессионален'), 3.479774077040767),
#  (('и', 'конские'), 3.479774077040767),
#  (('не', 'смог'), 3.4795345560815383),
#  (('надо', 'было'), 3.4777741276548877),
#  (('в', 'треде'), 3.477073337890082),
#  (('понимаешь', 'что'), 3.473922265990629),
#  (('думать', 'что'), 3.473922265990629),
#  (('том', 'что'), 3.473922265990629),
#  (('даже', 'лучше'), 3.4715435779042516),
#  (('в', 'качестве'), 3.469526132254699),
#  (('в', 'бизнесе'), 3.469526132254699),
#  (('у', 'которой'), 3.467631070690285),
#  (('на', 'работу'), 3.4625395778502974),
#  (('его', 'дело'), 3.459640362401427),
#  (('какие', 'нахуй'), 3.457459336455067),
#  (('ни', 'меня'), 3.4514917491576873),
#  (('уже', 'код'), 3.447076987412849),
#  (('в', 'голос'), 3.4413552552880025),
#  (('в', 'нем'), 3.4413552552880025),
#  (('в', 'могилу'), 3.4413552552880025),
#  (('только', 'один'), 3.4296672569865883),
#  (('а', 'также'), 3.4248939782339307),
#  (('на', 'камеру'), 3.413059520586928),
#  (('на', 'века'), 3.413059520586928),
#  (('не', 'плевать'), 3.4105416845945866),
#  (('в', 'небольшой'), 3.4005332607677476),
#  (('в', 'комнату'), 3.4005332607677476),
#  (('что', 'женщина'), 3.399814293836907),
#  (('такое', 'же'), 3.3967231012672343),
#  (('это', 'мои'), 3.3946676020851383),
#  (('разбираться', 'в'), 3.382514755265069),
#  (('не', 'вижу'), 3.3823708076278907),
#  (('вместе', 'с'), 3.374744194548459),
#  ...]

# %%
vectorizer = TfidfVectorizer(
    tokenizer=lambda x: x, lowercase=False, max_df=0.8, min_df=2,
    norm='l2'
).fit(cleared_docs)

# %%
pd.DataFrame(cleared_docs)
# Out:
#                  0               1             2              3   \
# 0               год         учиться           вуз  программистая
# 1               это  сформироваться        взгляд           ради
# 2             веган         плевать    окружающий          среда
# 3          здоровый       веганстве          None           None
# 4              лгбт             гей         бишки            всё
# 5            любить           любой    проявление        гейства
# 6               это          личный         выбор         каждый
# 7            хотеть          россия     проходить           лгбт
# 8                би         сексуал          None           None
# 9            почему           пофиг       человек     заниматься
# 10              век         женщина      угнетать     продолжать
# 11            право         женщина         нужно       уравнять
# 12          женщина        изменить        парень            муж
# 13           расист             это      наклеить       наклейка
# 14            наука           давно  опровергнуть            всё
# 15          человек         должный           всё   перемешаться
# 16              всё        здоровый    счастливый           None
# 17          русский         девушка   встречаться       кавказец
# 18          либерал            None          None           None
# 19          свобода         человек       превыше           весь
# 20           каждый            мочь        делать       захотеть
# 21          религия             это            яд        никакой
# 22            наука        помогать       большой        молитва
# 23          отличие        отсталый    постсовков        думеров
# 24            няшка            None          None           None
# 25           бампик            None          None           None
# 26         бампечек            None          None           None
# 27             бамп            None          None           None
# 28             None            None          None           None
# 29              год         учиться           вуз    программист
# ...             ...             ...           ...            ...
# 10347           всё          щемить          фикс           None
# 10348      запилить           стори          None           None
# 10349          двор            жить       паренёк       пиздюком
# 10350   встречаться           тёлка      соседний           двор
# 10351        любовь          пиздец           всё           прям
# 10352          None            None          None           None
# 10353        вдвоём    возвращаться        поздно        вечером
# 10354        пьяный           быдло      ответить          прямо
# 10355     следующий            день          день      проходить
# 10356      здоровый          хулить       уложить           двое
# 10357     проломить          голова      остаться        инвалид
# 10358        кинуть            None          None           None
# 10359         стать        помогать         никак        лежачий
# 10360          дело            None          None           None
# 10361     издохнуть            None          None           None
# 10362       стойкий            None          None           None
# 10363        жёстко      подставить       человек        который
# 10364         видео          особый          роль         играть
# 10365        видеть            баба        пиздил           None
# 10366        откуда           знать         бухой          блядь
# 10367            её          пиздил        почему            это
# 10368     собраться        защищать      семейный       конфликт
# 10369        просто         вызвать       полиция        сказать
# 10370        минута           наряд     приезжать       паковать
# 10371          мимо      бдительный     сторожить        подъезд
# 10372  обесточилчет           орнул          None           None
# 10373     прилететь         молодец          None           None
# 10374        двачую             это          None           None
# 10375       влезать       отношение         нахуй           None
# 10376          мочь         паренёк          урок           None
#
#                    4             5            6         7   \
# 0            являться       веганом         лгбт  активист
# 1             который       готовый     бороться      None
# 2              хотеть     причинять         вред  животное
# 3                None          None         None      None
# 4          небинарные           это        зайка      None
# 5                None          None         None      None
# 6                None          None         None      None
# 7               парад          None         None      None
# 8                None          None         None      None
# 9             спальня  поддерживать     феминизм   женщина
# 10                сей          пора         None      None
# 11          появиться       женщина       учёный  писатель
# 12                это            её         дело    абортя
# 13            надпись         идиот         None      None
# 14          положение        расизм         None      None
# 15               раса       таковой         None      None
# 16               None          None         None      None
# 17     афроамериканец           это    прекрасно      None
# 18               None          None         None      None
# 19               None          None         None      None
# 20                это       вредить  другимтакже   научный
# 21                бог          None         None      None
# 22          гордиться          свой    поколение      None
# 23           понимать           всё      простой      вещь
# 24               None          None         None      None
# 25               None          None         None      None
# 26               None          None         None      None
# 27               None          None         None      None
# 28               None          None         None      None
# 29           являться       веганом         лгбт  активист
# ...               ...           ...          ...       ...
# 10347            None          None         None      None
# 10348            None          None         None      None
# 10349             год      здоровый       пиздец      None
# 10350           девка      типичный        семья      отец
# 10351          ходить      говорить        шлюха     мамка
# 10352            None          None         None      None
# 10353           домой     проходить         мимо     школа
# 10354           лезть           это         жена      свой
# 10355            мимо         школа    подъехать   семёрка
# 10356         уложить          None         None      None
# 10357            овощ        ёбаный       думать   сделать
# 10358            None          None         None      None
# 10359          жирный      говорить        плохо      None
# 10360            None          None         None      None
# 10361            None          None         None      None
# 10362            None          None         None      None
# 10363       доверялон    подставить         None      None
# 10364          сугроб          тело      прятать      None
# 10365            None          None         None      None
# 10366        начаться     рандомная     истерика    синька
# 10367          видеть      фрагмент        видео      None
# 10368      незнакомый       человек        шизик     блядь
# 10369          обычно       подъезд       пьяный  наркоман
# 10370            None          None         None      None
# 10371            None          None         None      None
# 10372            None          None         None      None
# 10373            None          None         None      None
# 10374            None          None         None      None
# 10375            None          None         None      None
# 10376            None          None         None      None
#
#                        8            9   ...    66    67    68    69    70  \
# 0      мультикультуралист     феминист  ...  None  None  None  None  None
# 1                    None         None  ...  None  None  None  None  None
# 2                    None         None  ...  None  None  None  None  None
# 3                    None         None  ...  None  None  None  None  None
# 4                    None         None  ...  None  None  None  None  None
# 5                    None         None  ...  None  None  None  None  None
# 6                    None         None  ...  None  None  None  None  None
# 7                    None         None  ...  None  None  None  None  None
# 8                    None         None  ...  None  None  None  None  None
# 9              абсолютный       равный  ...  None  None  None  None  None
# 10                   None         None  ...  None  None  None  None  None
# 11                инженер      который  ...  None  None  None  None  None
# 12     мудьтикультаралист         None  ...  None  None  None  None  None
# 13                   None         None  ...  None  None  None  None  None
# 14                   None         None  ...  None  None  None  None  None
# 15                   None         None  ...  None  None  None  None  None
# 16                   None         None  ...  None  None  None  None  None
# 17                   None         None  ...  None  None  None  None  None
# 18                   None         None  ...  None  None  None  None  None
# 19                   None         None  ...  None  None  None  None  None
# 20                 атеист         None  ...  None  None  None  None  None
# 21                   None         None  ...  None  None  None  None  None
# 22                   None         None  ...  None  None  None  None  None
# 23                   весь        добро  ...  None  None  None  None  None
# 24                   None         None  ...  None  None  None  None  None
# 25                   None         None  ...  None  None  None  None  None
# 26                   None         None  ...  None  None  None  None  None
# 27                   None         None  ...  None  None  None  None  None
# 28                   None         None  ...  None  None  None  None  None
# 29     мультикультуралист     феминист  ...  None  None  None  None  None
# ...                   ...          ...  ...   ...   ...   ...   ...   ...
# 10347                None         None  ...  None  None  None  None  None
# 10348                None         None  ...  None  None  None  None  None
# 10349                None         None  ...  None  None  None  None  None
# 10350                мать        бабка  ...  None  None  None  None  None
# 10351            например           ой  ...  None  None  None  None  None
# 10352                None         None  ...  None  None  None  None  None
# 10353              парень     заметить  ...  None  None  None  None  None
# 10354            разговор       начать  ...  None  None  None  None  None
# 10355              оттуда        выйти  ...  None  None  None  None  None
# 10356                None         None  ...  None  None  None  None  None
# 10357                 тня         None  ...  None  None  None  None  None
# 10358                None         None  ...  None  None  None  None  None
# 10359                None         None  ...  None  None  None  None  None
# 10360                None         None  ...  None  None  None  None  None
# 10361                None         None  ...  None  None  None  None  None
# 10362                None         None  ...  None  None  None  None  None
# 10363                None         None  ...  None  None  None  None  None
# 10364                None         None  ...  None  None  None  None  None
# 10365                None         None  ...  None  None  None  None  None
# 10366                None         None  ...  None  None  None  None  None
# 10367                None         None  ...  None  None  None  None  None
# 10368                None         None  ...  None  None  None  None  None
# 10369              сидеть  агрессивный  ...  None  None  None  None  None
# 10370                None         None  ...  None  None  None  None  None
# 10371                None         None  ...  None  None  None  None  None
# 10372                None         None  ...  None  None  None  None  None
# 10373                None         None  ...  None  None  None  None  None
# 10374                None         None  ...  None  None  None  None  None
# 10375                None         None  ...  None  None  None  None  None
# 10376                None         None  ...  None  None  None  None  None
#
#          71    72    73    74    75
# 0      None  None  None  None  None
# 1      None  None  None  None  None
# 2      None  None  None  None  None
# 3      None  None  None  None  None
# 4      None  None  None  None  None
# 5      None  None  None  None  None
# 6      None  None  None  None  None
# 7      None  None  None  None  None
# 8      None  None  None  None  None
# 9      None  None  None  None  None
# 10     None  None  None  None  None
# 11     None  None  None  None  None
# 12     None  None  None  None  None
# 13     None  None  None  None  None
# 14     None  None  None  None  None
# 15     None  None  None  None  None
# 16     None  None  None  None  None
# 17     None  None  None  None  None
# 18     None  None  None  None  None
# 19     None  None  None  None  None
# 20     None  None  None  None  None
# 21     None  None  None  None  None
# 22     None  None  None  None  None
# 23     None  None  None  None  None
# 24     None  None  None  None  None
# 25     None  None  None  None  None
# 26     None  None  None  None  None
# 27     None  None  None  None  None
# 28     None  None  None  None  None
# 29     None  None  None  None  None
# ...     ...   ...   ...   ...   ...
# 10347  None  None  None  None  None
# 10348  None  None  None  None  None
# 10349  None  None  None  None  None
# 10350  None  None  None  None  None
# 10351  None  None  None  None  None
# 10352  None  None  None  None  None
# 10353  None  None  None  None  None
# 10354  None  None  None  None  None
# 10355  None  None  None  None  None
# 10356  None  None  None  None  None
# 10357  None  None  None  None  None
# 10358  None  None  None  None  None
# 10359  None  None  None  None  None
# 10360  None  None  None  None  None
# 10361  None  None  None  None  None
# 10362  None  None  None  None  None
# 10363  None  None  None  None  None
# 10364  None  None  None  None  None
# 10365  None  None  None  None  None
# 10366  None  None  None  None  None
# 10367  None  None  None  None  None
# 10368  None  None  None  None  None
# 10369  None  None  None  None  None
# 10370  None  None  None  None  None
# 10371  None  None  None  None  None
# 10372  None  None  None  None  None
# 10373  None  None  None  None  None
# 10374  None  None  None  None  None
# 10375  None  None  None  None  None
# 10376  None  None  None  None  None
#
# [10377 rows x 76 columns]

# %%
X_train_tfidf_lemmatized = vectorizer.transform(cleared_docs)
X_test_tfidf_lemmatized = vectorizer.transform(cleared_docs)

# %%
clf_tfidf_lemmatized = LogisticRegression(C=30.0, class_weight='balanced', solver='newton-cg', 
                         multi_class='multinomial', n_jobs=-1, random_state=40)
clf_tfidf_lemmatized.fit(X_train_tfidf_lemmatized, y_train)

y_predicted_tfidf_lemmatized = clf_tfidf.predict(X_test_tfidf_lemmatized)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-00bda0a4cee1> in <module>
#       1 clf_tfidf_lemmatized = LogisticRegression(C=30.0, class_weight='balanced', solver='newton-cg',
#       2                          multi_class='multinomial', n_jobs=-1, random_state=40)
# ----> 3 clf_tfidf_lemmatized.fit(X_train_tfidf_lemmatized, y_train)
#       4
#       5 y_predicted_tfidf_lemmatized = clf_tfidf.predict(X_test_tfidf_lemmatized)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1286
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1288                          accept_large_sparse=solver != 'liblinear')
#    1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     764         y = y.astype(np.float64)
#     765
# --> 766     check_consistent_length(X, y)
#     767
#     768     return X, y
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     233     if len(uniques) > 1:
#     234         raise ValueError("Found input variables with inconsistent numbers of"
# --> 235                          " samples: %r" % [int(l) for l in lengths])
#     236
#     237
#
# ValueError: Found input variables with inconsistent numbers of samples: [10377, 7263]
